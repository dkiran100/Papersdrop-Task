# %%
from newspaper import Article
import requests
from bs4 import BeautifulSoup
import urllib3
from requests.packages.urllib3.exceptions import InsecureRequestWarning
import re
from bs4 import BeautifulSoup 
import operator 
from collections import Counter
import string 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
txt = '''
Chronic diseases like Diabetes, heart attacks, cancer, arthritis etc can be described as health issues which last for around a year or more. These issues require regular medication, medical treatments and limitations in food and alcohol. They may cause difficulty in doing everyday activities such as getting dressed, going to the toilet, climbing stairs etc. These diseases have become most common among people in their late 40s. They may go away with time if provided with proper medical treatment. But in some cases, they may disrupt your life forever.

Why among people in their late 40s?

Usually, people in their late 40s are too busy focussing on their kids, their career and hence they go through a lot of stress and tension. And because of this they often ignore to take care of themselves, to maintain a healthy lifestyle and to work on their physical and mental well-being. They rarely take out time for themselves. This results in them having no social life of their own. Their ignorance ultimately leads to such chronic diseases.

The main causes of such issues are:

· Unhealthy lifestyle, no fixed sleeping pattern.

· Lack of physical workout: People tend to become lazy at this age and they avoid working on their body.

· Excessive alcohol and smoking: People try to forget their stress by liquor. Most of the times they get addicted to alcohol which further leads to various lungs and liver diseases.

· Poor nutrition: People avoid having a fully balanced meal. No proper consumption of fruits and vegetables.

· One of the major reasons would be stress and tension. People at this age feel stressed about financial problems, kids, future, relationships.

Apart from the above causes, what makes people in their 40s to be most prone to these diseases would be also because of hormonal changes in their bodies. Women and men both during this time go through menopause and manopause(andropause) respectively. Due to low levels of oestrogen and testosterone in women and men respectively, their bodies become vulnerable to such external diseases. That is why, this the age when people mostly get hypertension, high cholesterol levels, diabetes etc.

What are the major effects of a chronic illness?

A chronic illness can affect you mentally, physically and emotionally. Its symptoms are specific to the disease. For instance, a person with diabetes may have constant urge of urine, a person suffering from heart diseases may have pain in chest. These symptoms sometimes last lifetime and troubles a lot in the old age. Few common symptoms of chronic diseases are fatigue, pain, mental stress, mood disorders etc.

People in their 40s suffering from chronic health issues notice a change in their physical appearance, their skin becoming dull and they start getting wrinkles. These issues make them stay away from their social life and family gatherings. People don’t feel self-confident as they once used to be. They gradually start hating their own body which makes them prone to depression and anxiety. The stress builds up in their body which leads to frustration and choleric attitude. They feel helpless and can not do the daily activities properly. They feel the constant need for help from someone.

People get irritated easily and feel difficulty in handling their relationships. They are anxious most of the time and suffers from disturbed sleep. People are often seen complaining about body aches and fatigue. They lose interests in things which they once enjoyed doing.

How to take care of ourselves?

In most of the people these diseases are caused due to bad lifestyle choices and most of these are treatable with proper medication and care. We discussed why people in their late 40s are most vulnerable to such diseases. But that does not mean other age groups are safe. We all know prevention is better than cure, so it’s better to prevent such diseases by taking care of ourselves. Here are some of the healthy habits which can be adopted in daily life to eschew such diseases.

· Work on yourself physically, do yoga, walking, jogging or any other physical activity which interests you atleast 4 times a week. Staying healthy is most important. If your body functions properly, then you are safe from half of the diseases.

· Keeping yourself hydrated is the key of healthy lifestyle. Drink water around 6-8 glasses a day. Drinking Water ensures that every system in your body functions properly.

· Keep a check on your diet. Have a balanced meal. Replace junk food with fruits and nuts. If you want to have something junk, try to keep rest of the meals of the day light.

· Have warm water every morning with lemon, it removes toxins from your body. Try to end your day with light dinner and a cup of green tea. You will automatically start feeling healthy and fresh.

· Try to get atleast 7-8 hours of sleep every day. Getting a good night’s sleep is essential these days. Its important to rest your eyes and your brain. Well-rested people seem to handle stress better.

· Practise meditation to avoid stress and feel happy both mentally and physically.

· And last but not the least, spend time on things which makes your heart happy. Have family dinners with long conversations. Look at old photographs. Paint, travel, read, write, do whatever you used to do when you were young.

To conclude, we all know because of the pandemic, our lifestyle has been affected a lot and it’s difficult to maintain mental and physical well-being. Keeping faith and trusting ourselves is the only way of achieving that. People in their late 40s should take care of themselves to avoid such health risks. There is no need to worry and stress about it because advances in medicine have made the treatment of these diseases easy. But it’s always better to eschew things that can affect us in the future. People with chronic illness face extreme levels of stress. Make sure you follow all the health care tips about stress management.
'''

# %%
txt = txt.lower()
txt = txt.replace('\n','')
txt = txt.replace('.','')
txt = txt.replace(',','')
txt = txt.replace('?','')
txt
# Out:
# 'chronic diseases like diabetes heart attacks cancer arthritis etc can be described as health issues which last for around a year or more these issues require regular medication medical treatments and limitations in food and alcohol they may cause difficulty in doing everyday activities such as getting dressed going to the toilet climbing stairs etc these diseases have become most common among people in their late 40s they may go away with time if provided with proper medical treatment but in some cases they may disrupt your life foreverwhy among people in their late 40susually people in their late 40s are too busy focussing on their kids their career and hence they go through a lot of stress and tension and because of this they often ignore to take care of themselves to maintain a healthy lifestyle and to work on their physical and mental well-being they rarely take out time for themselves this results in them having no social life of their own their ignorance ultimately leads to su
# ...

# %%
stop_words = set(stopwords.words('english'))
stop_words = list(stop_words)
stop_words
# Out:
# ['very',
#  'your',
#  'doing',
#  'it',
#  'did',
#  's',
#  'this',
#  'for',
#  'while',
#  'weren',
#  'into',
#  "it's",
#  'most',
#  've',
#  'own',
#  'then',
#  "she's",
#  'she',
#  'the',
#  'be',
#  'm',
#  'those',
#  'both',
#  'yourselves',
#  'had',
#  'him',
#  'i',
#  'with',
#  "you've",
#  'through',
#  'hers',
#  'being',
#  'they',
#  'ain',
#  'just',
#  'whom',
#  'down',
#  'up',
#  'out',
#  'or',
#  'll',
#  "aren't",
#  'again',
#  "didn't",
#  'not',
#  'myself',
#  "that'll",
#  'couldn',
#  'more',
#  'as',
#  'itself',
#  'such',
#  'why',
#  'than',
#  'yourself',
#  "weren't",
#  'from',
#  'which',
#  'because',
#  'these',
#  'against',
#  'between',
#  'was',
#  'isn',
#  'of',
#  'how',
#  "hadn't",
#  'them',
#  'ma',
#  'but',
#  'will',
#  'wasn',
#  'some',
#  "shouldn't",
#  'y',
#  'were',
#  'in',
#  'o',
#  'by',
#  'same',
#  'me',
#  "shan't",
#  'no',
#  'what',
#  'mightn',
#  'wouldn',
#  'few',
#  'their',
#  'until',
#  'above',
# ...

# %%
l = txt.split(' ')
ls = txt.split(' ')
print("Number of words including stop words: " + str(len(l)))
# Out:
# Number of words including stop words: 982

# %%
unique_sw = []

for i in l:
    if i not in unique_sw:
        unique_sw.append(i)

print(unique_sw)
print("\n\nNumber of unique words including stop words:" + str(len(unique_sw)))
# Out:
# ['chronic', 'diseases', 'like', 'diabetes', 'heart', 'attacks', 'cancer', 'arthritis', 'etc', 'can', 'be', 'described', 'as', 'health', 'issues', 'which', 'last', 'for', 'around', 'a', 'year', 'or', 'more', 'these', 'require', 'regular', 'medication', 'medical', 'treatments', 'and', 'limitations', 'in', 'food', 'alcohol', 'they', 'may', 'cause', 'difficulty', 'doing', 'everyday', 'activities', 'such', 'getting', 'dressed', 'going', 'to', 'the', 'toilet', 'climbing', 'stairs', 'have', 'become', 'most', 'common', 'among', 'people', 'their', 'late', '40s', 'go', 'away', 'with', 'time', 'if', 'provided', 'proper', 'treatment', 'but', 'some', 'cases', 'disrupt', 'your', 'life', 'foreverwhy', '40susually', 'are', 'too', 'busy', 'focussing', 'on', 'kids', 'career', 'hence', 'through', 'lot', 'of', 'stress', 'tension', 'because', 'this', 'often', 'ignore', 'take', 'care', 'themselves', 'maintain', 'healthy', 'lifestyle', 'work', 'physical', 'mental', 'well-being', 'rarely', 'out', 'results',
# ...

# %%
words = []

for i in ls:
    if i not in stop_words:
        words.append(i)

print("Number of words without stop words: " + str(len(words)))
# Out:
# Number of words without stop words: 553

# %%
unique_nosw = []

for i in words:
    if i not in unique_nosw:
        unique_nosw.append(i)

print(unique_nosw)
print("\n\nNumber of unique words without stop words:" + str(len(unique_nosw)))
# Out:
# ['chronic', 'diseases', 'like', 'diabetes', 'heart', 'attacks', 'cancer', 'arthritis', 'etc', 'described', 'health', 'issues', 'last', 'around', 'year', 'require', 'regular', 'medication', 'medical', 'treatments', 'limitations', 'food', 'alcohol', 'may', 'cause', 'difficulty', 'everyday', 'activities', 'getting', 'dressed', 'going', 'toilet', 'climbing', 'stairs', 'become', 'common', 'among', 'people', 'late', '40s', 'go', 'away', 'time', 'provided', 'proper', 'treatment', 'cases', 'disrupt', 'life', 'foreverwhy', '40susually', 'busy', 'focussing', 'kids', 'career', 'hence', 'lot', 'stress', 'tension', 'often', 'ignore', 'take', 'care', 'maintain', 'healthy', 'lifestyle', 'work', 'physical', 'mental', 'well-being', 'rarely', 'results', 'social', 'ignorance', 'ultimately', 'leads', 'diseasesthe', 'main', 'causes', 'are:·', 'unhealthy', 'fixed', 'sleeping', 'pattern·', 'lack', 'workout:', 'tend', 'lazy', 'age', 'avoid', 'working', 'body·', 'excessive', 'smoking:', 'try', 'forget', 'liq
# ...

# %%
str1 = " "
str1 = str1.join(words)
str1
# Out:
# 'chronic diseases like diabetes heart attacks cancer arthritis etc described health issues last around year issues require regular medication medical treatments limitations food alcohol may cause difficulty everyday activities getting dressed going toilet climbing stairs etc diseases become common among people late 40s may go away time provided proper medical treatment cases may disrupt life foreverwhy among people late 40susually people late 40s busy focussing kids career hence go lot stress tension often ignore take care maintain healthy lifestyle work physical mental well-being rarely take time results social life ignorance ultimately leads chronic diseasesthe main causes issues are:· unhealthy lifestyle fixed sleeping pattern· lack physical workout: people tend become lazy age avoid working body· excessive alcohol smoking: people try forget stress liquor times get addicted alcohol leads various lungs liver diseases· poor nutrition: people avoid fully balanced meal proper consumpt
# ...

# %%
def N_grams(text,n):
    tokens = re.split("\\s+",text)
    ngrams = []
    for i in range(len(tokens)-n+1):
        temps = [tokens[j] for j in range(i,i+n)]
        ngrams.append(" ".join(temps))
    return ngrams

# %%
l1 = N_grams(str1,1)
l1
# Out:
# ['chronic',
#  'diseases',
#  'like',
#  'diabetes',
#  'heart',
#  'attacks',
#  'cancer',
#  'arthritis',
#  'etc',
#  'described',
#  'health',
#  'issues',
#  'last',
#  'around',
#  'year',
#  'issues',
#  'require',
#  'regular',
#  'medication',
#  'medical',
#  'treatments',
#  'limitations',
#  'food',
#  'alcohol',
#  'may',
#  'cause',
#  'difficulty',
#  'everyday',
#  'activities',
#  'getting',
#  'dressed',
#  'going',
#  'toilet',
#  'climbing',
#  'stairs',
#  'etc',
#  'diseases',
#  'become',
#  'common',
#  'among',
#  'people',
#  'late',
#  '40s',
#  'may',
#  'go',
#  'away',
#  'time',
#  'provided',
#  'proper',
#  'medical',
#  'treatment',
#  'cases',
#  'may',
#  'disrupt',
#  'life',
#  'foreverwhy',
#  'among',
#  'people',
#  'late',
#  '40susually',
#  'people',
#  'late',
#  '40s',
#  'busy',
#  'focussing',
#  'kids',
#  'career',
#  'hence',
#  'go',
#  'lot',
#  'stress',
#  'tension',
#  'often',
#  'ignore',
#  'take',
#  'care',
#  'maintain',
# ...

# %%
word_count1 = {}
 
for word in l1:
    if word in word_count1:
        word_count1[word] += 1
    else:
        word_count1[word] = 1

# %%
from collections import Counter
c = Counter(word_count1)
 
    # returns the most occurring elements
t = c.most_common(1000)

for i in range(len(t)):
    density = (t[i][1]/len(l))*100
    print(t[i],density,end = '\n')
top1 = c.most_common(1)
density1 = (top1[0][1]/len(l))*100
print(top1)
top1.append(density1)
# Out:
# ('people', 16) 1.6293279022403258
# ('diseases', 10) 1.0183299389002036
# ('stress', 10) 1.0183299389002036
# ('chronic', 7) 0.7128309572301426
# ('40s', 6) 0.6109979633401221
# ('care', 6) 0.6109979633401221
# ('feel', 6) 0.6109979633401221
# ('body', 6) 0.6109979633401221
# ('issues', 5) 0.5091649694501018
# ('may', 5) 0.5091649694501018
# ('late', 5) 0.5091649694501018
# ('time', 5) 0.5091649694501018
# ('healthy', 5) 0.5091649694501018
# ('lifestyle', 5) 0.5091649694501018
# ('physical', 5) 0.5091649694501018
# ('age', 5) 0.5091649694501018
# ('health', 4) 0.40733197556008144
# ('life', 4) 0.40733197556008144
# ('take', 4) 0.40733197556008144
# ('avoid', 4) 0.40733197556008144
# ('try', 4) 0.40733197556008144
# ('get', 4) 0.40733197556008144
# ('day', 4) 0.40733197556008144
# ('diabetes', 3) 0.30549898167006106
# ('heart', 3) 0.30549898167006106
# ('last', 3) 0.30549898167006106
# ('alcohol', 3) 0.30549898167006106
# ('getting', 3) 0.30549898167006106
# ...

# %%
l2 = N_grams(str1,2)
l2
# Out:
# ['chronic diseases',
#  'diseases like',
#  'like diabetes',
#  'diabetes heart',
#  'heart attacks',
#  'attacks cancer',
#  'cancer arthritis',
#  'arthritis etc',
#  'etc described',
#  'described health',
#  'health issues',
#  'issues last',
#  'last around',
#  'around year',
#  'year issues',
#  'issues require',
#  'require regular',
#  'regular medication',
#  'medication medical',
#  'medical treatments',
#  'treatments limitations',
#  'limitations food',
#  'food alcohol',
#  'alcohol may',
#  'may cause',
#  'cause difficulty',
#  'difficulty everyday',
#  'everyday activities',
#  'activities getting',
#  'getting dressed',
#  'dressed going',
#  'going toilet',
#  'toilet climbing',
#  'climbing stairs',
#  'stairs etc',
#  'etc diseases',
#  'diseases become',
#  'become common',
#  'common among',
#  'among people',
#  'people late',
#  'late 40s',
#  '40s may',
#  'may go',
#  'go away',
#  'away time',
#  'time provided',
#  'provided proper',
#  'proper medical',
# ...

# %%
word_count2 = {}
 
for word in l2:
    if word in word_count2:
        word_count2[word] += 1
    else:
        word_count2[word] = 1

# %%
c = Counter(word_count2)
 
    # returns the most occurring elements
t = c.most_common(500)
print(len(t))
for i in range(len(t)):
    density = (t[i][1]/len(t))*100
    print(t[i],density,end = '\n')
top2 = c.most_common(1)
density2 = (top2[0][1]/len(t))*100
print(top2)
top2.append(density2)
# Out:
# 500
# ('people late', 5) 1.0
# ('late 40s', 4) 0.8
# ('take care', 3) 0.6
# ('chronic diseases', 2) 0.4
# ('health issues', 2) 0.4
# ('among people', 2) 0.4
# ('stress tension', 2) 0.4
# ('healthy lifestyle', 2) 0.4
# ('social life', 2) 0.4
# ('balanced meal', 2) 0.4
# ('women men', 2) 0.4
# ('chronic illness', 2) 0.4
# ('body functions', 2) 0.4
# ('diseases like', 1) 0.2
# ('like diabetes', 1) 0.2
# ('diabetes heart', 1) 0.2
# ('heart attacks', 1) 0.2
# ('attacks cancer', 1) 0.2
# ('cancer arthritis', 1) 0.2
# ('arthritis etc', 1) 0.2
# ('etc described', 1) 0.2
# ('described health', 1) 0.2
# ('issues last', 1) 0.2
# ('last around', 1) 0.2
# ('around year', 1) 0.2
# ('year issues', 1) 0.2
# ('issues require', 1) 0.2
# ('require regular', 1) 0.2
# ('regular medication', 1) 0.2
# ('medication medical', 1) 0.2
# ('medical treatments', 1) 0.2
# ('treatments limitations', 1) 0.2
# ('limitations food', 1) 0.2
# ('food alcohol', 1) 0.2
# ('alcohol may', 1) 0.2
# ('may cause', 1) 0.2
# ...

# %%
l3 = N_grams(str1,3)
l3
# Out:
# ['chronic diseases like',
#  'diseases like diabetes',
#  'like diabetes heart',
#  'diabetes heart attacks',
#  'heart attacks cancer',
#  'attacks cancer arthritis',
#  'cancer arthritis etc',
#  'arthritis etc described',
#  'etc described health',
#  'described health issues',
#  'health issues last',
#  'issues last around',
#  'last around year',
#  'around year issues',
#  'year issues require',
#  'issues require regular',
#  'require regular medication',
#  'regular medication medical',
#  'medication medical treatments',
#  'medical treatments limitations',
#  'treatments limitations food',
#  'limitations food alcohol',
#  'food alcohol may',
#  'alcohol may cause',
#  'may cause difficulty',
#  'cause difficulty everyday',
#  'difficulty everyday activities',
#  'everyday activities getting',
#  'activities getting dressed',
#  'getting dressed going',
#  'dressed going toilet',
#  'going toilet climbing',
#  'toilet climbing stairs',
#  'climbing stairs etc',
# ...

# %%
word_count3 = {}
 
for word in l3:
    if word in word_count3:
        word_count3[word] += 1
    else:
        word_count3[word] = 1

# %%
c = Counter(word_count3)
 
    # returns the most occurring elements
t = c.most_common(1000)
print(len(t))
for i in range(len(t)):
    density = (t[i][1]/len(t))*100
    print(t[i],density,end = '\n')
top3 = c.most_common(1)
density3 = (top3[0][1]/len(t))*100
print(top3)
top3.append(density3)
# Out:
# 547
# ('people late 40s', 4) 0.7312614259597806
# ('among people late', 2) 0.3656307129798903
# ('chronic diseases like', 1) 0.18281535648994515
# ('diseases like diabetes', 1) 0.18281535648994515
# ('like diabetes heart', 1) 0.18281535648994515
# ('diabetes heart attacks', 1) 0.18281535648994515
# ('heart attacks cancer', 1) 0.18281535648994515
# ('attacks cancer arthritis', 1) 0.18281535648994515
# ('cancer arthritis etc', 1) 0.18281535648994515
# ('arthritis etc described', 1) 0.18281535648994515
# ('etc described health', 1) 0.18281535648994515
# ('described health issues', 1) 0.18281535648994515
# ('health issues last', 1) 0.18281535648994515
# ('issues last around', 1) 0.18281535648994515
# ('last around year', 1) 0.18281535648994515
# ('around year issues', 1) 0.18281535648994515
# ('year issues require', 1) 0.18281535648994515
# ('issues require regular', 1) 0.18281535648994515
# ('require regular medication', 1) 0.18281535648994515
# ...

# %%
f = []
f.append(top1)
f.append(top2)
f.append(top3)
f
# Out:
# [[('people', 16), 1.6293279022403258],
#  [('people late', 5), 1.0],
#  [('people late 40s', 4), 0.7312614259597806]]
