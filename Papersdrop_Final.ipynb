# %%
from newspaper import Article
import requests
from bs4 import BeautifulSoup
import urllib3
from requests.packages.urllib3.exceptions import InsecureRequestWarning
import re
from bs4 import BeautifulSoup 
import operator 
from collections import Counter
import string 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
txt = '''
Chronic diseases like Diabetes, heart attacks, cancer, arthritis etc can be described as health issues which last for around a year or more. These issues require regular medication, medical treatments and limitations in food and alcohol. They may cause difficulty in doing everyday activities such as getting dressed, going to the toilet, climbing stairs etc. These diseases have become most common among people in their late 40s. They may go away with time if provided with proper medical treatment. But in some cases, they may disrupt your life forever.

Why among people in their late 40s?

Usually, people in their late 40s are too busy focussing on their kids, their career and hence they go through a lot of stress and tension. And because of this they often ignore to take care of themselves, to maintain a healthy lifestyle and to work on their physical and mental well-being. They rarely take out time for themselves. This results in them having no social life of their own. Their ignorance ultimately leads to such chronic diseases.

The main causes of such issues are:

· Unhealthy lifestyle, no fixed sleeping pattern.

· Lack of physical workout: People tend to become lazy at this age and they avoid working on their body.

· Excessive alcohol and smoking: People try to forget their stress by liquor. Most of the times they get addicted to alcohol which further leads to various lungs and liver diseases.

· Poor nutrition: People avoid having a fully balanced meal. No proper consumption of fruits and vegetables.

· One of the major reasons would be stress and tension. People at this age feel stressed about financial problems, kids, future, relationships.

Apart from the above causes, what makes people in their 40s to be most prone to these diseases would be also because of hormonal changes in their bodies. Women and men both during this time go through menopause and manopause(andropause) respectively. Due to low levels of oestrogen and testosterone in women and men respectively, their bodies become vulnerable to such external diseases. That is why, this the age when people mostly get hypertension, high cholesterol levels, diabetes etc.

What are the major effects of a chronic illness?

A chronic illness can affect you mentally, physically and emotionally. Its symptoms are specific to the disease. For instance, a person with diabetes may have constant urge of urine, a person suffering from heart diseases may have pain in chest. These symptoms sometimes last lifetime and troubles a lot in the old age. Few common symptoms of chronic diseases are fatigue, pain, mental stress, mood disorders etc.

People in their 40s suffering from chronic health issues notice a change in their physical appearance, their skin becoming dull and they start getting wrinkles. These issues make them stay away from their social life and family gatherings. People don’t feel self-confident as they once used to be. They gradually start hating their own body which makes them prone to depression and anxiety. The stress builds up in their body which leads to frustration and choleric attitude. They feel helpless and can not do the daily activities properly. They feel the constant need for help from someone.

People get irritated easily and feel difficulty in handling their relationships. They are anxious most of the time and suffers from disturbed sleep. People are often seen complaining about body aches and fatigue. They lose interests in things which they once enjoyed doing.

How to take care of ourselves?

In most of the people these diseases are caused due to bad lifestyle choices and most of these are treatable with proper medication and care. We discussed why people in their late 40s are most vulnerable to such diseases. But that does not mean other age groups are safe. We all know prevention is better than cure, so it’s better to prevent such diseases by taking care of ourselves. Here are some of the healthy habits which can be adopted in daily life to eschew such diseases.

· Work on yourself physically, do yoga, walking, jogging or any other physical activity which interests you atleast 4 times a week. Staying healthy is most important. If your body functions properly, then you are safe from half of the diseases.

· Keeping yourself hydrated is the key of healthy lifestyle. Drink water around 6-8 glasses a day. Drinking Water ensures that every system in your body functions properly.

· Keep a check on your diet. Have a balanced meal. Replace junk food with fruits and nuts. If you want to have something junk, try to keep rest of the meals of the day light.

· Have warm water every morning with lemon, it removes toxins from your body. Try to end your day with light dinner and a cup of green tea. You will automatically start feeling healthy and fresh.

· Try to get atleast 7-8 hours of sleep every day. Getting a good night’s sleep is essential these days. Its important to rest your eyes and your brain. Well-rested people seem to handle stress better.

· Practise meditation to avoid stress and feel happy both mentally and physically.

· And last but not the least, spend time on things which makes your heart happy. Have family dinners with long conversations. Look at old photographs. Paint, travel, read, write, do whatever you used to do when you were young.

To conclude, we all know because of the pandemic, our lifestyle has been affected a lot and it’s difficult to maintain mental and physical well-being. Keeping faith and trusting ourselves is the only way of achieving that. People in their late 40s should take care of themselves to avoid such health risks. There is no need to worry and stress about it because advances in medicine have made the treatment of these diseases easy. But it’s always better to eschew things that can affect us in the future. People with chronic illness face extreme levels of stress. Make sure you follow all the health care tips about stress management.
'''

# %%
txt = txt.lower()
txt = txt.replace('\n','')
txt = txt.replace('.','')
txt = txt.replace(',','')
txt = txt.replace('?','')
txt
# Out:
# 'chronic diseases like diabetes heart attacks cancer arthritis etc can be described as health issues which last for around a year or more these issues require regular medication medical treatments and limitations in food and alcohol they may cause difficulty in doing everyday activities such as getting dressed going to the toilet climbing stairs etc these diseases have become most common among people in their late 40s they may go away with time if provided with proper medical treatment but in some cases they may disrupt your life foreverwhy among people in their late 40susually people in their late 40s are too busy focussing on their kids their career and hence they go through a lot of stress and tension and because of this they often ignore to take care of themselves to maintain a healthy lifestyle and to work on their physical and mental well-being they rarely take out time for themselves this results in them having no social life of their own their ignorance ultimately leads to such chronic diseasesthe main causes of such issues are:· unhealthy lifestyle no fixed sleeping pattern· lack of physical workout: people tend to become lazy at this age and they avoid working on their body· excessive alcohol and smoking: people try to forget their stress by liquor most of the times they get addicted to alcohol which further leads to various lungs and liver diseases· poor nutrition: people avoid having a fully balanced meal no proper consumption of fruits and vegetables· one of the major reasons would be stress and tension people at this age feel stressed about financial problems kids future relationshipsapart from the above causes what makes people in their 40s to be most prone to these diseases would be also because of hormonal changes in their bodies women and men both during this time go through menopause and manopause(andropause) respectively due to low levels of oestrogen and testosterone in women and men respectively their bodies become vulnerable to such external diseases that is why this the age when people mostly get hypertension high cholesterol levels diabetes etcwhat are the major effects of a chronic illnessa chronic illness can affect you mentally physically and emotionally its symptoms are specific to the disease for instance a person with diabetes may have constant urge of urine a person suffering from heart diseases may have pain in chest these symptoms sometimes last lifetime and troubles a lot in the old age few common symptoms of chronic diseases are fatigue pain mental stress mood disorders etcpeople in their 40s suffering from chronic health issues notice a change in their physical appearance their skin becoming dull and they start getting wrinkles these issues make them stay away from their social life and family gatherings people don’t feel self-confident as they once used to be they gradually start hating their own body which makes them prone to depression and anxiety the stress builds up in their body which leads to frustration and choleric attitude they feel helpless and can not do the daily activities properly they feel the constant need for help from someonepeople get irritated easily and feel difficulty in handling their relationships they are anxious most of the time and suffers from disturbed sleep people are often seen complaining about body aches and fatigue they lose interests in things which they once enjoyed doinghow to take care of ourselvesin most of the people these diseases are caused due to bad lifestyle choices and most of these are treatable with proper medication and care we discussed why people in their late 40s are most vulnerable to such diseases but that does not mean other age groups are safe we all know prevention is better than cure so it’s better to prevent such diseases by taking care of ourselves here are some of the healthy habits which can be adopted in daily life to eschew such diseases· work on yourself physically do yoga walking jogging or any other physical activity which  ...

# %%
stop_words = set(stopwords.words('english'))
stop_words = list(stop_words)
stop_words
# Out:
# ['yours',
#  'the',
#  "aren't",
#  "won't",
#  'before',
#  "she's",
#  'this',
#  'so',
#  'shouldn',
#  'weren',
#  'more',
#  'has',
#  'll',
#  'y',
#  'which',
#  'too',
#  "hasn't",
#  'above',
#  's',
#  'themselves',
#  'out',
#  'some',
#  "you've",
#  'they',
#  "that'll",
#  'don',
#  'not',
#  'been',
#  'when',
#  'doesn',
#  'by',
#  'does',
#  'just',
#  'd',
#  'and',
#  'there',
#  'them',
#  'mustn',
#  'most',
#  'he',
#  "you'll",
#  'under',
#  'hadn',
#  'isn',
#  'ours',
#  'your',
#  'but',
#  'do',
#  'yourself',
#  'all',
#  'am',
#  'own',
#  'than',
#  'why',
#  'an',
#  'down',
#  "mightn't",
#  'needn',
#  'him',
#  "wouldn't",
#  'its',
#  'should',
#  'i',
#  'being',
#  "shouldn't",
#  're',
#  'until',
#  'both',
#  'won',
#  'me',
#  'then',
#  'ain',
#  'after',
#  'these',
#  'here',
#  "didn't",
#  'through',
#  'are',
#  'was',
#  'did',
#  'whom',
#  'while',
#  'same',
#  'off',
#  "couldn't",
#  'were',
#  'his',
#  'any',
#  'because',
#  "needn't",
#  'again',
#  'few',
#  "hadn't",
#  'between',
#  'of',
#  'to',
#  "mustn't",
#  'our',
#  'where',
#  'ma',
#  'my',
#  "should've",
#  'had',
#  'aren',
#  'didn',
#  "doesn't",
#  'myself',
#  'you',
#  'each',
#  'will',
#  "isn't",
#  'ourselves',
#  'haven',
#  've',
#  't',
#  "weren't",
#  'it',
#  'nor',
#  'hasn',
#  'have',
#  'into',
#  'is',
#  'wasn',
#  'only',
#  'her',
#  'with',
#  "don't",
#  'for',
#  'once',
#  'how',
#  'can',
#  'such',
#  'we',
#  "it's",
#  'below',
#  'on',
#  'doing',
#  'm',
#  'a',
#  'at',
#  'further',
#  'now',
#  'theirs',
#  'itself',
#  "shan't",
#  'against',
#  'what',
#  'no',
#  'from',
#  'shan',
#  'herself',
#  'about',
#  'yourselves',
#  'she',
#  'very',
#  "wasn't",
#  'having',
#  'during',
#  'as',
#  'himself',
#  'their',
#  'or',
#  'if',
#  "you'd",
#  'that',
#  'over',
#  'mightn',
#  "haven't",
#  'who',
#  'other',
#  'be',
#  'wouldn',
#  'o',
#  'in',
#  'hers',
#  'up',
#  "you're",
#  'couldn',
#  'those']

# %%
l = txt.split(' ')
l
# Out:
# ['chronic',
#  'diseases',
#  'like',
#  'diabetes',
#  'heart',
#  'attacks',
#  'cancer',
#  'arthritis',
#  'etc',
#  'can',
#  'be',
#  'described',
#  'as',
#  'health',
#  'issues',
#  'which',
#  'last',
#  'for',
#  'around',
#  'a',
#  'year',
#  'or',
#  'more',
#  'these',
#  'issues',
#  'require',
#  'regular',
#  'medication',
#  'medical',
#  'treatments',
#  'and',
#  'limitations',
#  'in',
#  'food',
#  'and',
#  'alcohol',
#  'they',
#  'may',
#  'cause',
#  'difficulty',
#  'in',
#  'doing',
#  'everyday',
#  'activities',
#  'such',
#  'as',
#  'getting',
#  'dressed',
#  'going',
#  'to',
#  'the',
#  'toilet',
#  'climbing',
#  'stairs',
#  'etc',
#  'these',
#  'diseases',
#  'have',
#  'become',
#  'most',
#  'common',
#  'among',
#  'people',
#  'in',
#  'their',
#  'late',
#  '40s',
#  'they',
#  'may',
#  'go',
#  'away',
#  'with',
#  'time',
#  'if',
#  'provided',
#  'with',
#  'proper',
#  'medical',
#  'treatment',
#  'but',
#  'in',
#  'some',
#  'cases',
#  'they',
#  'may',
#  'disrupt',
#  'your',
#  'life',
#  'foreverwhy',
#  'among',
#  'people',
#  'in',
#  'their',
#  'late',
#  '40susually',
#  'people',
#  'in',
#  'their',
#  'late',
#  '40s',
#  'are',
#  'too',
#  'busy',
#  'focussing',
#  'on',
#  'their',
#  'kids',
#  'their',
#  'career',
#  'and',
#  'hence',
#  'they',
#  'go',
#  'through',
#  'a',
#  'lot',
#  'of',
#  'stress',
#  'and',
#  'tension',
#  'and',
#  'because',
#  'of',
#  'this',
#  'they',
#  'often',
#  'ignore',
#  'to',
#  'take',
#  'care',
#  'of',
#  'themselves',
#  'to',
#  'maintain',
#  'a',
#  'healthy',
#  'lifestyle',
#  'and',
#  'to',
#  'work',
#  'on',
#  'their',
#  'physical',
#  'and',
#  'mental',
#  'well-being',
#  'they',
#  'rarely',
#  'take',
#  'out',
#  'time',
#  'for',
#  'themselves',
#  'this',
#  'results',
#  'in',
#  'them',
#  'having',
#  'no',
#  'social',
#  'life',
#  'of',
#  'their',
#  'own',
#  'their',
#  'ignorance',
#  'ultimately',
#  'leads',
#  'to',
#  'such',
#  'chronic',
#  'diseasesthe',
#  'main',
#  'causes',
#  'of',
#  'such',
#  'issues',
#  'are:·',
#  'unhealthy',
#  'lifestyle',
#  'no',
#  'fixed',
#  'sleeping',
#  'pattern·',
#  'lack',
#  'of',
#  'physical',
#  'workout:',
#  'people',
#  'tend',
#  'to',
#  'become',
#  'lazy',
#  'at',
#  'this',
#  'age',
#  'and',
#  'they',
#  'avoid',
#  'working',
#  'on',
#  'their',
#  'body·',
#  'excessive',
#  'alcohol',
#  'and',
#  'smoking:',
#  'people',
#  'try',
#  'to',
#  'forget',
#  'their',
#  'stress',
#  'by',
#  'liquor',
#  'most',
#  'of',
#  'the',
#  'times',
#  'they',
#  'get',
#  'addicted',
#  'to',
#  'alcohol',
#  'which',
#  'further',
#  'leads',
#  'to',
#  'various',
#  'lungs',
#  'and',
#  'liver',
#  'diseases·',
#  'poor',
#  'nutrition:',
#  'people',
#  'avoid',
#  'having',
#  'a',
#  'fully',
#  'balanced',
#  'meal',
#  'no',
#  'proper',
#  'consumption',
#  'of',
#  'fruits',
#  'and',
#  'vegetables·',
#  'one',
#  'of',
#  'the',
#  'major',
#  'reasons',
#  'would',
#  'be',
#  'stress',
#  'and',
#  'tension',
#  'people',
#  'at',
#  'this',
#  'age',
#  'feel',
#  'stressed',
#  'about',
#  'financial',
#  'problems',
#  'kids',
#  'future',
#  'relationshipsapart',
#  'from',
#  'the',
#  'above',
#  'causes',
#  'what',
#  'makes',
#  'people',
#  'in',
#  'their',
#  '40s',
#  'to',
#  'be',
#  'most',
#  'prone',
#  'to',
#  'these',
#  'diseases',
#  'would',
#  'be',
#  'also',
#  'because',
#  'of',
#  'hormonal',
#  'changes',
#  'in',
#  'their',
#  'bodies',
#  'women',
#  'and',
#  'men',
#  'both',
#  'during',
#  'this',
#  'time',
#  'go',
#  'through',
#  'menopause',
#  'and',
#  'manopause(andropause)',
#  'respectively',
#  'due',
#  'to',
#  'low',
#  'levels',
#  'of',
#  'oestrogen',
#  'and',
#  'testosterone',
#  'in',
#  'women',
#  'and',
#  'men',
#  'respectively',
#  'their',
#  'bodies',
#  'become',
#  'vulnerable',
#  'to',
#  'such',
#  'external',
#  'diseases',
#  'that',
#  'is',
#  'why',
#  'this',
#  'the',
#  'age',
#  'when',
#  'people',
#  'mostly',
#  'get',
#  'hypertension',
#  'high',
#  'cholesterol',
#  'levels',
#  'diabetes',
#  'etcwhat',
#  'are',
#  'the',
#  'major',
#  'effects',
#  'of',
#  'a',
#  'chronic',
#  'illnessa',
#  'chronic',
#  'illness',
#  'can',
#  'affect',
#  'you',
#  'mentally',
#  'physically',
#  'and',
#  'emotionally',
#  'its',
#  'symptoms',
#  'are',
#  'specific',
#  'to',
#  'the',
#  'disease',
#  'for',
#  'instance',
#  'a',
#  'person',
#  'with',
#  'diabetes',
#  'may',
#  'have',
#  'constant',
#  'urge',
#  'of',
#  'urine',
#  'a',
#  'person',
#  'suffering',
#  'from',
#  'heart',
#  'diseases',
#  'may',
#  'have',
#  'pain',
#  'in',
#  'chest',
#  'these',
#  'symptoms',
#  'sometimes',
#  'last',
#  'lifetime',
#  'and',
#  'troubles',
#  'a',
#  'lot',
#  'in',
#  'the',
#  'old',
#  'age',
#  'few',
#  'common',
#  'symptoms',
#  'of',
#  'chronic',
#  'diseases',
#  'are',
#  'fatigue',
#  'pain',
#  'mental',
#  'stress',
#  'mood',
#  'disorders',
#  'etcpeople',
#  'in',
#  'their',
#  '40s',
#  'suffering',
#  'from',
#  'chronic',
#  'health',
#  'issues',
#  'notice',
#  'a',
#  'change',
#  'in',
#  'their',
#  'physical',
#  'appearance',
#  'their',
#  'skin',
#  'becoming',
#  'dull',
#  'and',
#  'they',
#  'start',
#  'getting',
#  'wrinkles',
#  'these',
#  'issues',
#  'make',
#  'them',
#  'stay',
#  'away',
#  'from',
#  'their',
#  'social',
#  'life',
#  'and',
#  'family',
#  'gatherings',
#  'people',
#  'don’t',
#  'feel',
#  'self-confident',
#  'as',
#  'they',
#  'once',
#  'used',
#  'to',
#  'be',
#  'they',
#  'gradually',
#  'start',
#  'hating',
#  'their',
#  'own',
#  'body',
#  'which',
#  'makes',
#  'them',
#  'prone',
#  'to',
#  'depression',
#  'and',
#  'anxiety',
#  'the',
#  'stress',
#  'builds',
#  'up',
#  'in',
#  'their',
#  'body',
#  'which',
#  'leads',
#  'to',
#  'frustration',
#  'and',
#  'choleric',
#  'attitude',
#  'they',
#  'feel',
#  'helpless',
#  'and',
#  'can',
#  'not',
#  'do',
#  'the',
#  'daily',
#  'activities',
#  'properly',
#  'they',
#  'feel',
#  'the',
#  'constant',
#  'need',
#  'for',
#  'help',
#  'from',
#  'someonepeople',
#  'get',
#  'irritated',
#  'easily',
#  'and',
#  'feel',
#  'difficulty',
#  'in',
#  'handling',
#  'their',
#  'relationships',
#  'they',
#  'are',
#  'anxious',
#  'most',
#  'of',
#  'the',
#  'time',
#  'and',
#  'suffers',
#  'from',
#  'disturbed',
#  'sleep',
#  'people',
#  'are',
#  'often',
#  'seen',
#  'complaining',
#  'about',
#  'body',
#  'aches',
#  'and',
#  'fatigue',
#  'they',
#  'lose',
#  'interests',
#  'in',
#  'things',
#  'which',
#  'they',
#  'once',
#  'enjoyed',
#  'doinghow',
#  'to',
#  'take',
#  'care',
#  'of',
#  'ourselvesin',
#  'most',
#  'of',
#  'the',
#  'people',
#  'these',
#  'diseases',
#  'are',
#  'caused',
#  'due',
#  'to',
#  'bad',
#  'lifestyle',
#  'choices',
#  'and',
#  'most',
#  'of',
#  'these',
#  'are',
#  'treatable',
#  'with',
#  'proper',
#  'medication',
#  'and',
#  'care',
#  'we',
#  'discussed',
#  'why',
#  'people',
#  'in',
#  'their',
#  'late',
#  '40s',
#  'are',
#  'most',
#  'vulnerable',
#  'to',
#  'such',
#  'diseases',
#  'but',
#  'that',
#  'does',
#  'not',
#  'mean',
#  'other',
#  'age',
#  'groups',
#  'are',
#  'safe',
#  'we',
#  'all',
#  'know',
#  'prevention',
#  'is',
#  'better',
#  'than',
#  'cure',
#  'so',
#  'it’s',
#  'better',
#  'to',
#  'prevent',
#  'such',
#  'diseases',
#  'by',
#  'taking',
#  'care',
#  'of',
#  'ourselves',
#  'here',
#  'are',
#  'some',
#  'of',
#  'the',
#  'healthy',
#  'habits',
#  'which',
#  'can',
#  'be',
#  'adopted',
#  'in',
#  'daily',
#  'life',
#  'to',
#  'eschew',
#  'such',
#  'diseases·',
#  'work',
#  'on',
#  'yourself',
#  'physically',
#  'do',
#  'yoga',
#  'walking',
#  'jogging',
#  'or',
#  'any',
#  'other',
#  'physical',
#  'activity',
#  'which',
#  'interests',
#  'you',
#  'atleast',
#  '4',
#  'times',
#  'a',
#  'week',
#  'staying',
#  'healthy',
#  'is',
#  'most',
#  'important',
#  'if',
#  'your',
#  'body',
#  'functions',
#  'properly',
#  'then',
#  'you',
#  'are',
#  'safe',
#  'from',
#  'half',
#  'of',
#  'the',
#  'diseases·',
#  'keeping',
#  'yourself',
#  'hydrated',
#  'is',
#  'the',
#  'key',
#  'of',
#  'healthy',
#  'lifestyle',
#  'drink',
#  'water',
#  'around',
#  '6-8',
#  'glasses',
#  'a',
#  'day',
#  'drinking',
#  'water',
#  'ensures',
#  'that',
#  'every',
#  'system',
#  'in',
#  'your',
#  'body',
#  'functions',
#  'properly·',
#  'keep',
#  'a',
#  'check',
#  'on',
#  'your',
#  'diet',
#  'have',
#  'a',
#  'balanced',
#  'meal',
#  'replace',
#  'junk',
#  'food',
#  'with',
#  'fruits',
#  'and',
#  'nuts',
#  'if',
#  'you',
#  'want',
#  'to',
#  'have',
#  'something',
#  'junk',
#  'try',
#  'to',
#  'keep',
#  'rest',
#  'of',
#  'the',
#  'meals',
#  'of',
#  'the',
#  'day',
#  'light·',
#  'have',
#  'warm',
#  'water',
#  'every',
#  'morning',
#  'with',
#  'lemon',
#  'it',
#  'removes',
#  'toxins',
#  'from',
#  'your',
#  'body',
#  'try',
#  'to',
#  'end',
#  'your',
#  'day',
#  'with',
#  'light',
#  'dinner',
#  'and',
#  'a',
#  'cup',
#  'of',
#  'green',
#  'tea',
#  'you',
#  'will',
#  'automatically',
#  'start',
#  'feeling',
#  'healthy',
#  'and',
#  'fresh·',
#  'try',
#  'to',
#  'get',
#  'atleast',
#  '7-8',
#  'hours',
#  'of',
#  'sleep',
#  'every',
#  'day',
#  'getting',
#  'a',
#  'good',
#  'night’s',
#  'sleep',
#  'is',
#  'essential',
#  'these',
#  'days',
#  'its',
#  'important',
#  'to',
#  'rest',
#  'your',
#  'eyes',
#  'and',
#  'your',
#  'brain',
#  'well-rested',
#  'people',
#  'seem',
#  'to',
#  'handle',
#  'stress',
#  'better·',
#  'practise',
#  'meditation',
#  'to',
#  'avoid',
#  'stress',
#  'and',
#  'feel',
#  'happy',
#  'both',
#  'mentally',
#  'and',
#  'physically·',
#  'and',
#  'last',
#  'but',
#  'not',
#  'the',
#  'least',
#  'spend',
#  'time',
#  'on',
#  'things',
#  'which',
#  'makes',
#  'your',
#  'heart',
#  'happy',
#  'have',
#  'family',
#  'dinners',
#  'with',
#  'long',
#  'conversations',
#  'look',
#  'at',
#  'old',
#  'photographs',
#  'paint',
#  'travel',
#  'read',
#  'write',
#  'do',
#  'whatever',
#  'you',
#  'used',
#  'to',
#  'do',
#  'when',
#  'you',
#  'were',
#  'youngto',
#  'conclude',
#  'we',
#  'all',
#  'know',
#  'because',
#  'of',
#  'the',
#  'pandemic',
#  'our',
#  'lifestyle',
#  'has',
#  'been',
#  'affected',
#  'a',
#  'lot',
#  'and',
#  'it’s',
#  'difficult',
#  'to',
#  'maintain',
#  'mental',
#  'and',
#  'physical',
#  'well-being',
#  'keeping',
#  'faith',
#  'and',
#  'trusting',
#  'ourselves',
#  'is',
#  'the',
#  'only',
#  'way',
#  'of',
#  'achieving',
#  'that',
#  'people',
#  'in',
#  'their',
#  'late',
#  '40s',
#  'should',
#  'take',
#  'care',
#  'of',
#  'themselves',
#  'to',
#  'avoid',
#  'such',
#  'health',
#  'risks',
#  'there',
#  'is',
#  'no',
#  'need',
#  'to',
#  'worry',
#  'and',
#  'stress',
#  'about',
#  'it',
#  'because',
#  'advances',
#  'in',
#  'medicine',
#  'have',
#  'made',
#  'the',
#  'treatment',
#  'of',
#  'these',
#  'diseases',
#  'easy',
#  'but',
#  'it’s',
#  'always',
#  'better',
#  'to',
#  'eschew',
#  'things',
#  'that',
#  'can',
#  'affect',
#  'us',
#  'in',
#  'the',
#  'future',
#  'people',
#  'with',
#  'chronic',
#  'illness',
#  'face',
#  'extreme',
#  'levels',
#  'of',
#  'stress',
#  'make',
#  'sure',
#  'you',
#  'follow',
#  'all',
#  'the',
#  'health',
#  'care',
#  'tips',
#  'about',
#  'stress',
#  'management']

# %%
words = []

for i in l:
    if i not in stop_words:
        words.append(i)

words
# Out:
# ['chronic',
#  'diseases',
#  'like',
#  'diabetes',
#  'heart',
#  'attacks',
#  'cancer',
#  'arthritis',
#  'etc',
#  'described',
#  'health',
#  'issues',
#  'last',
#  'around',
#  'year',
#  'issues',
#  'require',
#  'regular',
#  'medication',
#  'medical',
#  'treatments',
#  'limitations',
#  'food',
#  'alcohol',
#  'may',
#  'cause',
#  'difficulty',
#  'everyday',
#  'activities',
#  'getting',
#  'dressed',
#  'going',
#  'toilet',
#  'climbing',
#  'stairs',
#  'etc',
#  'diseases',
#  'become',
#  'common',
#  'among',
#  'people',
#  'late',
#  '40s',
#  'may',
#  'go',
#  'away',
#  'time',
#  'provided',
#  'proper',
#  'medical',
#  'treatment',
#  'cases',
#  'may',
#  'disrupt',
#  'life',
#  'foreverwhy',
#  'among',
#  'people',
#  'late',
#  '40susually',
#  'people',
#  'late',
#  '40s',
#  'busy',
#  'focussing',
#  'kids',
#  'career',
#  'hence',
#  'go',
#  'lot',
#  'stress',
#  'tension',
#  'often',
#  'ignore',
#  'take',
#  'care',
#  'maintain',
#  'healthy',
#  'lifestyle',
#  'work',
#  'physical',
#  'mental',
#  'well-being',
#  'rarely',
#  'take',
#  'time',
#  'results',
#  'social',
#  'life',
#  'ignorance',
#  'ultimately',
#  'leads',
#  'chronic',
#  'diseasesthe',
#  'main',
#  'causes',
#  'issues',
#  'are:·',
#  'unhealthy',
#  'lifestyle',
#  'fixed',
#  'sleeping',
#  'pattern·',
#  'lack',
#  'physical',
#  'workout:',
#  'people',
#  'tend',
#  'become',
#  'lazy',
#  'age',
#  'avoid',
#  'working',
#  'body·',
#  'excessive',
#  'alcohol',
#  'smoking:',
#  'people',
#  'try',
#  'forget',
#  'stress',
#  'liquor',
#  'times',
#  'get',
#  'addicted',
#  'alcohol',
#  'leads',
#  'various',
#  'lungs',
#  'liver',
#  'diseases·',
#  'poor',
#  'nutrition:',
#  'people',
#  'avoid',
#  'fully',
#  'balanced',
#  'meal',
#  'proper',
#  'consumption',
#  'fruits',
#  'vegetables·',
#  'one',
#  'major',
#  'reasons',
#  'would',
#  'stress',
#  'tension',
#  'people',
#  'age',
#  'feel',
#  'stressed',
#  'financial',
#  'problems',
#  'kids',
#  'future',
#  'relationshipsapart',
#  'causes',
#  'makes',
#  'people',
#  '40s',
#  'prone',
#  'diseases',
#  'would',
#  'also',
#  'hormonal',
#  'changes',
#  'bodies',
#  'women',
#  'men',
#  'time',
#  'go',
#  'menopause',
#  'manopause(andropause)',
#  'respectively',
#  'due',
#  'low',
#  'levels',
#  'oestrogen',
#  'testosterone',
#  'women',
#  'men',
#  'respectively',
#  'bodies',
#  'become',
#  'vulnerable',
#  'external',
#  'diseases',
#  'age',
#  'people',
#  'mostly',
#  'get',
#  'hypertension',
#  'high',
#  'cholesterol',
#  'levels',
#  'diabetes',
#  'etcwhat',
#  'major',
#  'effects',
#  'chronic',
#  'illnessa',
#  'chronic',
#  'illness',
#  'affect',
#  'mentally',
#  'physically',
#  'emotionally',
#  'symptoms',
#  'specific',
#  'disease',
#  'instance',
#  'person',
#  'diabetes',
#  'may',
#  'constant',
#  'urge',
#  'urine',
#  'person',
#  'suffering',
#  'heart',
#  'diseases',
#  'may',
#  'pain',
#  'chest',
#  'symptoms',
#  'sometimes',
#  'last',
#  'lifetime',
#  'troubles',
#  'lot',
#  'old',
#  'age',
#  'common',
#  'symptoms',
#  'chronic',
#  'diseases',
#  'fatigue',
#  'pain',
#  'mental',
#  'stress',
#  'mood',
#  'disorders',
#  'etcpeople',
#  '40s',
#  'suffering',
#  'chronic',
#  'health',
#  'issues',
#  'notice',
#  'change',
#  'physical',
#  'appearance',
#  'skin',
#  'becoming',
#  'dull',
#  'start',
#  'getting',
#  'wrinkles',
#  'issues',
#  'make',
#  'stay',
#  'away',
#  'social',
#  'life',
#  'family',
#  'gatherings',
#  'people',
#  'don’t',
#  'feel',
#  'self-confident',
#  'used',
#  'gradually',
#  'start',
#  'hating',
#  'body',
#  'makes',
#  'prone',
#  'depression',
#  'anxiety',
#  'stress',
#  'builds',
#  'body',
#  'leads',
#  'frustration',
#  'choleric',
#  'attitude',
#  'feel',
#  'helpless',
#  'daily',
#  'activities',
#  'properly',
#  'feel',
#  'constant',
#  'need',
#  'help',
#  'someonepeople',
#  'get',
#  'irritated',
#  'easily',
#  'feel',
#  'difficulty',
#  'handling',
#  'relationships',
#  'anxious',
#  'time',
#  'suffers',
#  'disturbed',
#  'sleep',
#  'people',
#  'often',
#  'seen',
#  'complaining',
#  'body',
#  'aches',
#  'fatigue',
#  'lose',
#  'interests',
#  'things',
#  'enjoyed',
#  'doinghow',
#  'take',
#  'care',
#  'ourselvesin',
#  'people',
#  'diseases',
#  'caused',
#  'due',
#  'bad',
#  'lifestyle',
#  'choices',
#  'treatable',
#  'proper',
#  'medication',
#  'care',
#  'discussed',
#  'people',
#  'late',
#  '40s',
#  'vulnerable',
#  'diseases',
#  'mean',
#  'age',
#  'groups',
#  'safe',
#  'know',
#  'prevention',
#  'better',
#  'cure',
#  'it’s',
#  'better',
#  'prevent',
#  'diseases',
#  'taking',
#  'care',
#  'healthy',
#  'habits',
#  'adopted',
#  'daily',
#  'life',
#  'eschew',
#  'diseases·',
#  'work',
#  'physically',
#  'yoga',
#  'walking',
#  'jogging',
#  'physical',
#  'activity',
#  'interests',
#  'atleast',
#  '4',
#  'times',
#  'week',
#  'staying',
#  'healthy',
#  'important',
#  'body',
#  'functions',
#  'properly',
#  'safe',
#  'half',
#  'diseases·',
#  'keeping',
#  'hydrated',
#  'key',
#  'healthy',
#  'lifestyle',
#  'drink',
#  'water',
#  'around',
#  '6-8',
#  'glasses',
#  'day',
#  'drinking',
#  'water',
#  'ensures',
#  'every',
#  'system',
#  'body',
#  'functions',
#  'properly·',
#  'keep',
#  'check',
#  'diet',
#  'balanced',
#  'meal',
#  'replace',
#  'junk',
#  'food',
#  'fruits',
#  'nuts',
#  'want',
#  'something',
#  'junk',
#  'try',
#  'keep',
#  'rest',
#  'meals',
#  'day',
#  'light·',
#  'warm',
#  'water',
#  'every',
#  'morning',
#  'lemon',
#  'removes',
#  'toxins',
#  'body',
#  'try',
#  'end',
#  'day',
#  'light',
#  'dinner',
#  'cup',
#  'green',
#  'tea',
#  'automatically',
#  'start',
#  'feeling',
#  'healthy',
#  'fresh·',
#  'try',
#  'get',
#  'atleast',
#  '7-8',
#  'hours',
#  'sleep',
#  'every',
#  'day',
#  'getting',
#  'good',
#  'night’s',
#  'sleep',
#  'essential',
#  'days',
#  'important',
#  'rest',
#  'eyes',
#  'brain',
#  'well-rested',
#  'people',
#  'seem',
#  'handle',
#  'stress',
#  'better·',
#  'practise',
#  'meditation',
#  'avoid',
#  'stress',
#  'feel',
#  'happy',
#  'mentally',
#  'physically·',
#  'last',
#  'least',
#  'spend',
#  'time',
#  'things',
#  'makes',
#  'heart',
#  'happy',
#  'family',
#  'dinners',
#  'long',
#  'conversations',
#  'look',
#  'old',
#  'photographs',
#  'paint',
#  'travel',
#  'read',
#  'write',
#  'whatever',
#  'used',
#  'youngto',
#  'conclude',
#  'know',
#  'pandemic',
#  'lifestyle',
#  'affected',
#  'lot',
#  'it’s',
#  'difficult',
#  'maintain',
#  'mental',
#  'physical',
#  'well-being',
#  'keeping',
#  'faith',
#  'trusting',
#  'way',
#  'achieving',
#  'people',
#  'late',
#  '40s',
#  'take',
#  'care',
#  'avoid',
#  'health',
#  'risks',
#  'need',
#  'worry',
#  'stress',
#  'advances',
#  'medicine',
#  'made',
#  'treatment',
#  'diseases',
#  'easy',
#  'it’s',
#  'always',
#  'better',
#  'eschew',
#  'things',
#  'affect',
#  'us',
#  'future',
#  'people',
#  'chronic',
#  'illness',
#  'face',
#  'extreme',
#  'levels',
#  'stress',
#  'make',
#  'sure',
#  'follow',
#  'health',
#  'care',
#  'tips',
#  'stress',
#  'management']

# %%
str1 = " "
str1 = str1.join(words)
str1
# Out:
# 'chronic diseases like diabetes heart attacks cancer arthritis etc described health issues last around year issues require regular medication medical treatments limitations food alcohol may cause difficulty everyday activities getting dressed going toilet climbing stairs etc diseases become common among people late 40s may go away time provided proper medical treatment cases may disrupt life foreverwhy among people late 40susually people late 40s busy focussing kids career hence go lot stress tension often ignore take care maintain healthy lifestyle work physical mental well-being rarely take time results social life ignorance ultimately leads chronic diseasesthe main causes issues are:· unhealthy lifestyle fixed sleeping pattern· lack physical workout: people tend become lazy age avoid working body· excessive alcohol smoking: people try forget stress liquor times get addicted alcohol leads various lungs liver diseases· poor nutrition: people avoid fully balanced meal proper consumption fruits vegetables· one major reasons would stress tension people age feel stressed financial problems kids future relationshipsapart causes makes people 40s prone diseases would also hormonal changes bodies women men time go menopause manopause(andropause) respectively due low levels oestrogen testosterone women men respectively bodies become vulnerable external diseases age people mostly get hypertension high cholesterol levels diabetes etcwhat major effects chronic illnessa chronic illness affect mentally physically emotionally symptoms specific disease instance person diabetes may constant urge urine person suffering heart diseases may pain chest symptoms sometimes last lifetime troubles lot old age common symptoms chronic diseases fatigue pain mental stress mood disorders etcpeople 40s suffering chronic health issues notice change physical appearance skin becoming dull start getting wrinkles issues make stay away social life family gatherings people don’t feel self-confident used gradually start hating body makes prone depression anxiety stress builds body leads frustration choleric attitude feel helpless daily activities properly feel constant need help someonepeople get irritated easily feel difficulty handling relationships anxious time suffers disturbed sleep people often seen complaining body aches fatigue lose interests things enjoyed doinghow take care ourselvesin people diseases caused due bad lifestyle choices treatable proper medication care discussed people late 40s vulnerable diseases mean age groups safe know prevention better cure it’s better prevent diseases taking care healthy habits adopted daily life eschew diseases· work physically yoga walking jogging physical activity interests atleast 4 times week staying healthy important body functions properly safe half diseases· keeping hydrated key healthy lifestyle drink water around 6-8 glasses day drinking water ensures every system body functions properly· keep check diet balanced meal replace junk food fruits nuts want something junk try keep rest meals day light· warm water every morning lemon removes toxins body try end day light dinner cup green tea automatically start feeling healthy fresh· try get atleast 7-8 hours sleep every day getting good night’s sleep essential days important rest eyes brain well-rested people seem handle stress better· practise meditation avoid stress feel happy mentally physically· last least spend time things makes heart happy family dinners long conversations look old photographs paint travel read write whatever used youngto conclude know pandemic lifestyle affected lot it’s difficult maintain mental physical well-being keeping faith trusting way achieving people late 40s take care avoid health risks need worry stress advances medicine made treatment diseases easy it’s always better eschew things affect us future people chronic illness face extreme levels stress make sure follow health care tips stress management'

# %%
def N_grams(text,n):
    tokens = re.split("\\s+",text)
    ngrams = []
    for i in range(len(tokens)-n+1):
        temps = [tokens[j] for j in range(i,i+n)]
        ngrams.append(" ".join(temps))
    return ngrams

# %%
l1 = N_grams(str1,1)
l1
# Out:
# ['chronic',
#  'diseases',
#  'like',
#  'diabetes',
#  'heart',
#  'attacks',
#  'cancer',
#  'arthritis',
#  'etc',
#  'described',
#  'health',
#  'issues',
#  'last',
#  'around',
#  'year',
#  'issues',
#  'require',
#  'regular',
#  'medication',
#  'medical',
#  'treatments',
#  'limitations',
#  'food',
#  'alcohol',
#  'may',
#  'cause',
#  'difficulty',
#  'everyday',
#  'activities',
#  'getting',
#  'dressed',
#  'going',
#  'toilet',
#  'climbing',
#  'stairs',
#  'etc',
#  'diseases',
#  'become',
#  'common',
#  'among',
#  'people',
#  'late',
#  '40s',
#  'may',
#  'go',
#  'away',
#  'time',
#  'provided',
#  'proper',
#  'medical',
#  'treatment',
#  'cases',
#  'may',
#  'disrupt',
#  'life',
#  'foreverwhy',
#  'among',
#  'people',
#  'late',
#  '40susually',
#  'people',
#  'late',
#  '40s',
#  'busy',
#  'focussing',
#  'kids',
#  'career',
#  'hence',
#  'go',
#  'lot',
#  'stress',
#  'tension',
#  'often',
#  'ignore',
#  'take',
#  'care',
#  'maintain',
#  'healthy',
#  'lifestyle',
#  'work',
#  'physical',
#  'mental',
#  'well-being',
#  'rarely',
#  'take',
#  'time',
#  'results',
#  'social',
#  'life',
#  'ignorance',
#  'ultimately',
#  'leads',
#  'chronic',
#  'diseasesthe',
#  'main',
#  'causes',
#  'issues',
#  'are:·',
#  'unhealthy',
#  'lifestyle',
#  'fixed',
#  'sleeping',
#  'pattern·',
#  'lack',
#  'physical',
#  'workout:',
#  'people',
#  'tend',
#  'become',
#  'lazy',
#  'age',
#  'avoid',
#  'working',
#  'body·',
#  'excessive',
#  'alcohol',
#  'smoking:',
#  'people',
#  'try',
#  'forget',
#  'stress',
#  'liquor',
#  'times',
#  'get',
#  'addicted',
#  'alcohol',
#  'leads',
#  'various',
#  'lungs',
#  'liver',
#  'diseases·',
#  'poor',
#  'nutrition:',
#  'people',
#  'avoid',
#  'fully',
#  'balanced',
#  'meal',
#  'proper',
#  'consumption',
#  'fruits',
#  'vegetables·',
#  'one',
#  'major',
#  'reasons',
#  'would',
#  'stress',
#  'tension',
#  'people',
#  'age',
#  'feel',
#  'stressed',
#  'financial',
#  'problems',
#  'kids',
#  'future',
#  'relationshipsapart',
#  'causes',
#  'makes',
#  'people',
#  '40s',
#  'prone',
#  'diseases',
#  'would',
#  'also',
#  'hormonal',
#  'changes',
#  'bodies',
#  'women',
#  'men',
#  'time',
#  'go',
#  'menopause',
#  'manopause(andropause)',
#  'respectively',
#  'due',
#  'low',
#  'levels',
#  'oestrogen',
#  'testosterone',
#  'women',
#  'men',
#  'respectively',
#  'bodies',
#  'become',
#  'vulnerable',
#  'external',
#  'diseases',
#  'age',
#  'people',
#  'mostly',
#  'get',
#  'hypertension',
#  'high',
#  'cholesterol',
#  'levels',
#  'diabetes',
#  'etcwhat',
#  'major',
#  'effects',
#  'chronic',
#  'illnessa',
#  'chronic',
#  'illness',
#  'affect',
#  'mentally',
#  'physically',
#  'emotionally',
#  'symptoms',
#  'specific',
#  'disease',
#  'instance',
#  'person',
#  'diabetes',
#  'may',
#  'constant',
#  'urge',
#  'urine',
#  'person',
#  'suffering',
#  'heart',
#  'diseases',
#  'may',
#  'pain',
#  'chest',
#  'symptoms',
#  'sometimes',
#  'last',
#  'lifetime',
#  'troubles',
#  'lot',
#  'old',
#  'age',
#  'common',
#  'symptoms',
#  'chronic',
#  'diseases',
#  'fatigue',
#  'pain',
#  'mental',
#  'stress',
#  'mood',
#  'disorders',
#  'etcpeople',
#  '40s',
#  'suffering',
#  'chronic',
#  'health',
#  'issues',
#  'notice',
#  'change',
#  'physical',
#  'appearance',
#  'skin',
#  'becoming',
#  'dull',
#  'start',
#  'getting',
#  'wrinkles',
#  'issues',
#  'make',
#  'stay',
#  'away',
#  'social',
#  'life',
#  'family',
#  'gatherings',
#  'people',
#  'don’t',
#  'feel',
#  'self-confident',
#  'used',
#  'gradually',
#  'start',
#  'hating',
#  'body',
#  'makes',
#  'prone',
#  'depression',
#  'anxiety',
#  'stress',
#  'builds',
#  'body',
#  'leads',
#  'frustration',
#  'choleric',
#  'attitude',
#  'feel',
#  'helpless',
#  'daily',
#  'activities',
#  'properly',
#  'feel',
#  'constant',
#  'need',
#  'help',
#  'someonepeople',
#  'get',
#  'irritated',
#  'easily',
#  'feel',
#  'difficulty',
#  'handling',
#  'relationships',
#  'anxious',
#  'time',
#  'suffers',
#  'disturbed',
#  'sleep',
#  'people',
#  'often',
#  'seen',
#  'complaining',
#  'body',
#  'aches',
#  'fatigue',
#  'lose',
#  'interests',
#  'things',
#  'enjoyed',
#  'doinghow',
#  'take',
#  'care',
#  'ourselvesin',
#  'people',
#  'diseases',
#  'caused',
#  'due',
#  'bad',
#  'lifestyle',
#  'choices',
#  'treatable',
#  'proper',
#  'medication',
#  'care',
#  'discussed',
#  'people',
#  'late',
#  '40s',
#  'vulnerable',
#  'diseases',
#  'mean',
#  'age',
#  'groups',
#  'safe',
#  'know',
#  'prevention',
#  'better',
#  'cure',
#  'it’s',
#  'better',
#  'prevent',
#  'diseases',
#  'taking',
#  'care',
#  'healthy',
#  'habits',
#  'adopted',
#  'daily',
#  'life',
#  'eschew',
#  'diseases·',
#  'work',
#  'physically',
#  'yoga',
#  'walking',
#  'jogging',
#  'physical',
#  'activity',
#  'interests',
#  'atleast',
#  '4',
#  'times',
#  'week',
#  'staying',
#  'healthy',
#  'important',
#  'body',
#  'functions',
#  'properly',
#  'safe',
#  'half',
#  'diseases·',
#  'keeping',
#  'hydrated',
#  'key',
#  'healthy',
#  'lifestyle',
#  'drink',
#  'water',
#  'around',
#  '6-8',
#  'glasses',
#  'day',
#  'drinking',
#  'water',
#  'ensures',
#  'every',
#  'system',
#  'body',
#  'functions',
#  'properly·',
#  'keep',
#  'check',
#  'diet',
#  'balanced',
#  'meal',
#  'replace',
#  'junk',
#  'food',
#  'fruits',
#  'nuts',
#  'want',
#  'something',
#  'junk',
#  'try',
#  'keep',
#  'rest',
#  'meals',
#  'day',
#  'light·',
#  'warm',
#  'water',
#  'every',
#  'morning',
#  'lemon',
#  'removes',
#  'toxins',
#  'body',
#  'try',
#  'end',
#  'day',
#  'light',
#  'dinner',
#  'cup',
#  'green',
#  'tea',
#  'automatically',
#  'start',
#  'feeling',
#  'healthy',
#  'fresh·',
#  'try',
#  'get',
#  'atleast',
#  '7-8',
#  'hours',
#  'sleep',
#  'every',
#  'day',
#  'getting',
#  'good',
#  'night’s',
#  'sleep',
#  'essential',
#  'days',
#  'important',
#  'rest',
#  'eyes',
#  'brain',
#  'well-rested',
#  'people',
#  'seem',
#  'handle',
#  'stress',
#  'better·',
#  'practise',
#  'meditation',
#  'avoid',
#  'stress',
#  'feel',
#  'happy',
#  'mentally',
#  'physically·',
#  'last',
#  'least',
#  'spend',
#  'time',
#  'things',
#  'makes',
#  'heart',
#  'happy',
#  'family',
#  'dinners',
#  'long',
#  'conversations',
#  'look',
#  'old',
#  'photographs',
#  'paint',
#  'travel',
#  'read',
#  'write',
#  'whatever',
#  'used',
#  'youngto',
#  'conclude',
#  'know',
#  'pandemic',
#  'lifestyle',
#  'affected',
#  'lot',
#  'it’s',
#  'difficult',
#  'maintain',
#  'mental',
#  'physical',
#  'well-being',
#  'keeping',
#  'faith',
#  'trusting',
#  'way',
#  'achieving',
#  'people',
#  'late',
#  '40s',
#  'take',
#  'care',
#  'avoid',
#  'health',
#  'risks',
#  'need',
#  'worry',
#  'stress',
#  'advances',
#  'medicine',
#  'made',
#  'treatment',
#  'diseases',
#  'easy',
#  'it’s',
#  'always',
#  'better',
#  'eschew',
#  'things',
#  'affect',
#  'us',
#  'future',
#  'people',
#  'chronic',
#  'illness',
#  'face',
#  'extreme',
#  'levels',
#  'stress',
#  'make',
#  'sure',
#  'follow',
#  'health',
#  'care',
#  'tips',
#  'stress',
#  'management']

# %%
word_count1 = {}
 
for word in l1:
    if word in word_count1:
        word_count1[word] += 1
    else:
        word_count1[word] = 1

# %%
from collections import Counter
c = Counter(word_count1)
 
    # returns the most occurring elements
t = c.most_common(50)
top1 = c.most_common(1)
density1 = (top1[0][1]/len(l1))*100
print(t)
print(top1)
top1.append(density1)
# Out:
# [('people', 16), ('diseases', 10), ('stress', 10), ('chronic', 7), ('40s', 6), ('care', 6), ('feel', 6), ('body', 6), ('issues', 5), ('may', 5), ('late', 5), ('time', 5), ('healthy', 5), ('lifestyle', 5), ('physical', 5), ('age', 5), ('health', 4), ('life', 4), ('take', 4), ('avoid', 4), ('try', 4), ('get', 4), ('day', 4), ('diabetes', 3), ('heart', 3), ('last', 3), ('alcohol', 3), ('getting', 3), ('become', 3), ('go', 3), ('proper', 3), ('lot', 3), ('mental', 3), ('leads', 3), ('diseases·', 3), ('makes', 3), ('levels', 3), ('symptoms', 3), ('start', 3), ('sleep', 3), ('things', 3), ('better', 3), ('it’s', 3), ('water', 3), ('every', 3), ('etc', 2), ('around', 2), ('medication', 2), ('medical', 2), ('food', 2)]
# [('people', 16)]

# %%
l2 = N_grams(str1,2)
l2
# Out:
# ['chronic diseases',
#  'diseases like',
#  'like diabetes',
#  'diabetes heart',
#  'heart attacks',
#  'attacks cancer',
#  'cancer arthritis',
#  'arthritis etc',
#  'etc described',
#  'described health',
#  'health issues',
#  'issues last',
#  'last around',
#  'around year',
#  'year issues',
#  'issues require',
#  'require regular',
#  'regular medication',
#  'medication medical',
#  'medical treatments',
#  'treatments limitations',
#  'limitations food',
#  'food alcohol',
#  'alcohol may',
#  'may cause',
#  'cause difficulty',
#  'difficulty everyday',
#  'everyday activities',
#  'activities getting',
#  'getting dressed',
#  'dressed going',
#  'going toilet',
#  'toilet climbing',
#  'climbing stairs',
#  'stairs etc',
#  'etc diseases',
#  'diseases become',
#  'become common',
#  'common among',
#  'among people',
#  'people late',
#  'late 40s',
#  '40s may',
#  'may go',
#  'go away',
#  'away time',
#  'time provided',
#  'provided proper',
#  'proper medical',
#  'medical treatment',
#  'treatment cases',
#  'cases may',
#  'may disrupt',
#  'disrupt life',
#  'life foreverwhy',
#  'foreverwhy among',
#  'among people',
#  'people late',
#  'late 40susually',
#  '40susually people',
#  'people late',
#  'late 40s',
#  '40s busy',
#  'busy focussing',
#  'focussing kids',
#  'kids career',
#  'career hence',
#  'hence go',
#  'go lot',
#  'lot stress',
#  'stress tension',
#  'tension often',
#  'often ignore',
#  'ignore take',
#  'take care',
#  'care maintain',
#  'maintain healthy',
#  'healthy lifestyle',
#  'lifestyle work',
#  'work physical',
#  'physical mental',
#  'mental well-being',
#  'well-being rarely',
#  'rarely take',
#  'take time',
#  'time results',
#  'results social',
#  'social life',
#  'life ignorance',
#  'ignorance ultimately',
#  'ultimately leads',
#  'leads chronic',
#  'chronic diseasesthe',
#  'diseasesthe main',
#  'main causes',
#  'causes issues',
#  'issues are:·',
#  'are:· unhealthy',
#  'unhealthy lifestyle',
#  'lifestyle fixed',
#  'fixed sleeping',
#  'sleeping pattern·',
#  'pattern· lack',
#  'lack physical',
#  'physical workout:',
#  'workout: people',
#  'people tend',
#  'tend become',
#  'become lazy',
#  'lazy age',
#  'age avoid',
#  'avoid working',
#  'working body·',
#  'body· excessive',
#  'excessive alcohol',
#  'alcohol smoking:',
#  'smoking: people',
#  'people try',
#  'try forget',
#  'forget stress',
#  'stress liquor',
#  'liquor times',
#  'times get',
#  'get addicted',
#  'addicted alcohol',
#  'alcohol leads',
#  'leads various',
#  'various lungs',
#  'lungs liver',
#  'liver diseases·',
#  'diseases· poor',
#  'poor nutrition:',
#  'nutrition: people',
#  'people avoid',
#  'avoid fully',
#  'fully balanced',
#  'balanced meal',
#  'meal proper',
#  'proper consumption',
#  'consumption fruits',
#  'fruits vegetables·',
#  'vegetables· one',
#  'one major',
#  'major reasons',
#  'reasons would',
#  'would stress',
#  'stress tension',
#  'tension people',
#  'people age',
#  'age feel',
#  'feel stressed',
#  'stressed financial',
#  'financial problems',
#  'problems kids',
#  'kids future',
#  'future relationshipsapart',
#  'relationshipsapart causes',
#  'causes makes',
#  'makes people',
#  'people 40s',
#  '40s prone',
#  'prone diseases',
#  'diseases would',
#  'would also',
#  'also hormonal',
#  'hormonal changes',
#  'changes bodies',
#  'bodies women',
#  'women men',
#  'men time',
#  'time go',
#  'go menopause',
#  'menopause manopause(andropause)',
#  'manopause(andropause) respectively',
#  'respectively due',
#  'due low',
#  'low levels',
#  'levels oestrogen',
#  'oestrogen testosterone',
#  'testosterone women',
#  'women men',
#  'men respectively',
#  'respectively bodies',
#  'bodies become',
#  'become vulnerable',
#  'vulnerable external',
#  'external diseases',
#  'diseases age',
#  'age people',
#  'people mostly',
#  'mostly get',
#  'get hypertension',
#  'hypertension high',
#  'high cholesterol',
#  'cholesterol levels',
#  'levels diabetes',
#  'diabetes etcwhat',
#  'etcwhat major',
#  'major effects',
#  'effects chronic',
#  'chronic illnessa',
#  'illnessa chronic',
#  'chronic illness',
#  'illness affect',
#  'affect mentally',
#  'mentally physically',
#  'physically emotionally',
#  'emotionally symptoms',
#  'symptoms specific',
#  'specific disease',
#  'disease instance',
#  'instance person',
#  'person diabetes',
#  'diabetes may',
#  'may constant',
#  'constant urge',
#  'urge urine',
#  'urine person',
#  'person suffering',
#  'suffering heart',
#  'heart diseases',
#  'diseases may',
#  'may pain',
#  'pain chest',
#  'chest symptoms',
#  'symptoms sometimes',
#  'sometimes last',
#  'last lifetime',
#  'lifetime troubles',
#  'troubles lot',
#  'lot old',
#  'old age',
#  'age common',
#  'common symptoms',
#  'symptoms chronic',
#  'chronic diseases',
#  'diseases fatigue',
#  'fatigue pain',
#  'pain mental',
#  'mental stress',
#  'stress mood',
#  'mood disorders',
#  'disorders etcpeople',
#  'etcpeople 40s',
#  '40s suffering',
#  'suffering chronic',
#  'chronic health',
#  'health issues',
#  'issues notice',
#  'notice change',
#  'change physical',
#  'physical appearance',
#  'appearance skin',
#  'skin becoming',
#  'becoming dull',
#  'dull start',
#  'start getting',
#  'getting wrinkles',
#  'wrinkles issues',
#  'issues make',
#  'make stay',
#  'stay away',
#  'away social',
#  'social life',
#  'life family',
#  'family gatherings',
#  'gatherings people',
#  'people don’t',
#  'don’t feel',
#  'feel self-confident',
#  'self-confident used',
#  'used gradually',
#  'gradually start',
#  'start hating',
#  'hating body',
#  'body makes',
#  'makes prone',
#  'prone depression',
#  'depression anxiety',
#  'anxiety stress',
#  'stress builds',
#  'builds body',
#  'body leads',
#  'leads frustration',
#  'frustration choleric',
#  'choleric attitude',
#  'attitude feel',
#  'feel helpless',
#  'helpless daily',
#  'daily activities',
#  'activities properly',
#  'properly feel',
#  'feel constant',
#  'constant need',
#  'need help',
#  'help someonepeople',
#  'someonepeople get',
#  'get irritated',
#  'irritated easily',
#  'easily feel',
#  'feel difficulty',
#  'difficulty handling',
#  'handling relationships',
#  'relationships anxious',
#  'anxious time',
#  'time suffers',
#  'suffers disturbed',
#  'disturbed sleep',
#  'sleep people',
#  'people often',
#  'often seen',
#  'seen complaining',
#  'complaining body',
#  'body aches',
#  'aches fatigue',
#  'fatigue lose',
#  'lose interests',
#  'interests things',
#  'things enjoyed',
#  'enjoyed doinghow',
#  'doinghow take',
#  'take care',
#  'care ourselvesin',
#  'ourselvesin people',
#  'people diseases',
#  'diseases caused',
#  'caused due',
#  'due bad',
#  'bad lifestyle',
#  'lifestyle choices',
#  'choices treatable',
#  'treatable proper',
#  'proper medication',
#  'medication care',
#  'care discussed',
#  'discussed people',
#  'people late',
#  'late 40s',
#  '40s vulnerable',
#  'vulnerable diseases',
#  'diseases mean',
#  'mean age',
#  'age groups',
#  'groups safe',
#  'safe know',
#  'know prevention',
#  'prevention better',
#  'better cure',
#  'cure it’s',
#  'it’s better',
#  'better prevent',
#  'prevent diseases',
#  'diseases taking',
#  'taking care',
#  'care healthy',
#  'healthy habits',
#  'habits adopted',
#  'adopted daily',
#  'daily life',
#  'life eschew',
#  'eschew diseases·',
#  'diseases· work',
#  'work physically',
#  'physically yoga',
#  'yoga walking',
#  'walking jogging',
#  'jogging physical',
#  'physical activity',
#  'activity interests',
#  'interests atleast',
#  'atleast 4',
#  '4 times',
#  'times week',
#  'week staying',
#  'staying healthy',
#  'healthy important',
#  'important body',
#  'body functions',
#  'functions properly',
#  'properly safe',
#  'safe half',
#  'half diseases·',
#  'diseases· keeping',
#  'keeping hydrated',
#  'hydrated key',
#  'key healthy',
#  'healthy lifestyle',
#  'lifestyle drink',
#  'drink water',
#  'water around',
#  'around 6-8',
#  '6-8 glasses',
#  'glasses day',
#  'day drinking',
#  'drinking water',
#  'water ensures',
#  'ensures every',
#  'every system',
#  'system body',
#  'body functions',
#  'functions properly·',
#  'properly· keep',
#  'keep check',
#  'check diet',
#  'diet balanced',
#  'balanced meal',
#  'meal replace',
#  'replace junk',
#  'junk food',
#  'food fruits',
#  'fruits nuts',
#  'nuts want',
#  'want something',
#  'something junk',
#  'junk try',
#  'try keep',
#  'keep rest',
#  'rest meals',
#  'meals day',
#  'day light·',
#  'light· warm',
#  'warm water',
#  'water every',
#  'every morning',
#  'morning lemon',
#  'lemon removes',
#  'removes toxins',
#  'toxins body',
#  'body try',
#  'try end',
#  'end day',
#  'day light',
#  'light dinner',
#  'dinner cup',
#  'cup green',
#  'green tea',
#  'tea automatically',
#  'automatically start',
#  'start feeling',
#  'feeling healthy',
#  'healthy fresh·',
#  'fresh· try',
#  'try get',
#  'get atleast',
#  'atleast 7-8',
#  '7-8 hours',
#  'hours sleep',
#  'sleep every',
#  'every day',
#  'day getting',
#  'getting good',
#  'good night’s',
#  'night’s sleep',
#  'sleep essential',
#  'essential days',
#  'days important',
#  'important rest',
#  'rest eyes',
#  'eyes brain',
#  'brain well-rested',
#  'well-rested people',
#  'people seem',
#  'seem handle',
#  'handle stress',
#  'stress better·',
#  'better· practise',
#  'practise meditation',
#  'meditation avoid',
#  'avoid stress',
#  'stress feel',
#  'feel happy',
#  'happy mentally',
#  'mentally physically·',
#  'physically· last',
#  'last least',
#  'least spend',
#  'spend time',
#  'time things',
#  'things makes',
#  'makes heart',
#  'heart happy',
#  'happy family',
#  'family dinners',
#  'dinners long',
#  'long conversations',
#  'conversations look',
#  'look old',
#  'old photographs',
#  'photographs paint',
#  'paint travel',
#  'travel read',
#  'read write',
#  'write whatever',
#  'whatever used',
#  'used youngto',
#  'youngto conclude',
#  'conclude know',
#  'know pandemic',
#  'pandemic lifestyle',
#  'lifestyle affected',
#  'affected lot',
#  'lot it’s',
#  'it’s difficult',
#  'difficult maintain',
#  'maintain mental',
#  'mental physical',
#  'physical well-being',
#  'well-being keeping',
#  'keeping faith',
#  'faith trusting',
#  'trusting way',
#  'way achieving',
#  'achieving people',
#  'people late',
#  'late 40s',
#  '40s take',
#  'take care',
#  'care avoid',
#  'avoid health',
#  'health risks',
#  'risks need',
#  'need worry',
#  'worry stress',
#  'stress advances',
#  'advances medicine',
#  'medicine made',
#  'made treatment',
#  'treatment diseases',
#  'diseases easy',
#  'easy it’s',
#  'it’s always',
#  'always better',
#  'better eschew',
#  'eschew things',
#  'things affect',
#  'affect us',
#  'us future',
#  'future people',
#  'people chronic',
#  'chronic illness',
#  'illness face',
#  'face extreme',
#  'extreme levels',
#  'levels stress',
#  'stress make',
#  'make sure',
#  'sure follow',
#  'follow health',
#  'health care',
#  'care tips',
#  'tips stress',
#  'stress management']

# %%
word_count2 = {}
 
for word in l2:
    if word in word_count2:
        word_count2[word] += 1
    else:
        word_count2[word] = 1

# %%
c = Counter(word_count2)
 
    # returns the most occurring elements
t = c.most_common(50)
top2 = c.most_common(1)
density2 = (top2[0][1]/len(l2))*100
print(t)
print(top2)
top2.append(density2)
# Out:
# [('people late', 5), ('late 40s', 4), ('take care', 3), ('chronic diseases', 2), ('health issues', 2), ('among people', 2), ('stress tension', 2), ('healthy lifestyle', 2), ('social life', 2), ('balanced meal', 2), ('women men', 2), ('chronic illness', 2), ('body functions', 2), ('diseases like', 1), ('like diabetes', 1), ('diabetes heart', 1), ('heart attacks', 1), ('attacks cancer', 1), ('cancer arthritis', 1), ('arthritis etc', 1), ('etc described', 1), ('described health', 1), ('issues last', 1), ('last around', 1), ('around year', 1), ('year issues', 1), ('issues require', 1), ('require regular', 1), ('regular medication', 1), ('medication medical', 1), ('medical treatments', 1), ('treatments limitations', 1), ('limitations food', 1), ('food alcohol', 1), ('alcohol may', 1), ('may cause', 1), ('cause difficulty', 1), ('difficulty everyday', 1), ('everyday activities', 1), ('activities getting', 1), ('getting dressed', 1), ('dressed going', 1), ('going toilet', 1), ('toilet climbing', 1), ('climbing stairs', 1), ('stairs etc', 1), ('etc diseases', 1), ('diseases become', 1), ('become common', 1), ('common among', 1)]
# [('people late', 5)]

# %%
l3 = N_grams(str1,3)
l3
# Out:
# ['chronic diseases like',
#  'diseases like diabetes',
#  'like diabetes heart',
#  'diabetes heart attacks',
#  'heart attacks cancer',
#  'attacks cancer arthritis',
#  'cancer arthritis etc',
#  'arthritis etc described',
#  'etc described health',
#  'described health issues',
#  'health issues last',
#  'issues last around',
#  'last around year',
#  'around year issues',
#  'year issues require',
#  'issues require regular',
#  'require regular medication',
#  'regular medication medical',
#  'medication medical treatments',
#  'medical treatments limitations',
#  'treatments limitations food',
#  'limitations food alcohol',
#  'food alcohol may',
#  'alcohol may cause',
#  'may cause difficulty',
#  'cause difficulty everyday',
#  'difficulty everyday activities',
#  'everyday activities getting',
#  'activities getting dressed',
#  'getting dressed going',
#  'dressed going toilet',
#  'going toilet climbing',
#  'toilet climbing stairs',
#  'climbing stairs etc',
#  'stairs etc diseases',
#  'etc diseases become',
#  'diseases become common',
#  'become common among',
#  'common among people',
#  'among people late',
#  'people late 40s',
#  'late 40s may',
#  '40s may go',
#  'may go away',
#  'go away time',
#  'away time provided',
#  'time provided proper',
#  'provided proper medical',
#  'proper medical treatment',
#  'medical treatment cases',
#  'treatment cases may',
#  'cases may disrupt',
#  'may disrupt life',
#  'disrupt life foreverwhy',
#  'life foreverwhy among',
#  'foreverwhy among people',
#  'among people late',
#  'people late 40susually',
#  'late 40susually people',
#  '40susually people late',
#  'people late 40s',
#  'late 40s busy',
#  '40s busy focussing',
#  'busy focussing kids',
#  'focussing kids career',
#  'kids career hence',
#  'career hence go',
#  'hence go lot',
#  'go lot stress',
#  'lot stress tension',
#  'stress tension often',
#  'tension often ignore',
#  'often ignore take',
#  'ignore take care',
#  'take care maintain',
#  'care maintain healthy',
#  'maintain healthy lifestyle',
#  'healthy lifestyle work',
#  'lifestyle work physical',
#  'work physical mental',
#  'physical mental well-being',
#  'mental well-being rarely',
#  'well-being rarely take',
#  'rarely take time',
#  'take time results',
#  'time results social',
#  'results social life',
#  'social life ignorance',
#  'life ignorance ultimately',
#  'ignorance ultimately leads',
#  'ultimately leads chronic',
#  'leads chronic diseasesthe',
#  'chronic diseasesthe main',
#  'diseasesthe main causes',
#  'main causes issues',
#  'causes issues are:·',
#  'issues are:· unhealthy',
#  'are:· unhealthy lifestyle',
#  'unhealthy lifestyle fixed',
#  'lifestyle fixed sleeping',
#  'fixed sleeping pattern·',
#  'sleeping pattern· lack',
#  'pattern· lack physical',
#  'lack physical workout:',
#  'physical workout: people',
#  'workout: people tend',
#  'people tend become',
#  'tend become lazy',
#  'become lazy age',
#  'lazy age avoid',
#  'age avoid working',
#  'avoid working body·',
#  'working body· excessive',
#  'body· excessive alcohol',
#  'excessive alcohol smoking:',
#  'alcohol smoking: people',
#  'smoking: people try',
#  'people try forget',
#  'try forget stress',
#  'forget stress liquor',
#  'stress liquor times',
#  'liquor times get',
#  'times get addicted',
#  'get addicted alcohol',
#  'addicted alcohol leads',
#  'alcohol leads various',
#  'leads various lungs',
#  'various lungs liver',
#  'lungs liver diseases·',
#  'liver diseases· poor',
#  'diseases· poor nutrition:',
#  'poor nutrition: people',
#  'nutrition: people avoid',
#  'people avoid fully',
#  'avoid fully balanced',
#  'fully balanced meal',
#  'balanced meal proper',
#  'meal proper consumption',
#  'proper consumption fruits',
#  'consumption fruits vegetables·',
#  'fruits vegetables· one',
#  'vegetables· one major',
#  'one major reasons',
#  'major reasons would',
#  'reasons would stress',
#  'would stress tension',
#  'stress tension people',
#  'tension people age',
#  'people age feel',
#  'age feel stressed',
#  'feel stressed financial',
#  'stressed financial problems',
#  'financial problems kids',
#  'problems kids future',
#  'kids future relationshipsapart',
#  'future relationshipsapart causes',
#  'relationshipsapart causes makes',
#  'causes makes people',
#  'makes people 40s',
#  'people 40s prone',
#  '40s prone diseases',
#  'prone diseases would',
#  'diseases would also',
#  'would also hormonal',
#  'also hormonal changes',
#  'hormonal changes bodies',
#  'changes bodies women',
#  'bodies women men',
#  'women men time',
#  'men time go',
#  'time go menopause',
#  'go menopause manopause(andropause)',
#  'menopause manopause(andropause) respectively',
#  'manopause(andropause) respectively due',
#  'respectively due low',
#  'due low levels',
#  'low levels oestrogen',
#  'levels oestrogen testosterone',
#  'oestrogen testosterone women',
#  'testosterone women men',
#  'women men respectively',
#  'men respectively bodies',
#  'respectively bodies become',
#  'bodies become vulnerable',
#  'become vulnerable external',
#  'vulnerable external diseases',
#  'external diseases age',
#  'diseases age people',
#  'age people mostly',
#  'people mostly get',
#  'mostly get hypertension',
#  'get hypertension high',
#  'hypertension high cholesterol',
#  'high cholesterol levels',
#  'cholesterol levels diabetes',
#  'levels diabetes etcwhat',
#  'diabetes etcwhat major',
#  'etcwhat major effects',
#  'major effects chronic',
#  'effects chronic illnessa',
#  'chronic illnessa chronic',
#  'illnessa chronic illness',
#  'chronic illness affect',
#  'illness affect mentally',
#  'affect mentally physically',
#  'mentally physically emotionally',
#  'physically emotionally symptoms',
#  'emotionally symptoms specific',
#  'symptoms specific disease',
#  'specific disease instance',
#  'disease instance person',
#  'instance person diabetes',
#  'person diabetes may',
#  'diabetes may constant',
#  'may constant urge',
#  'constant urge urine',
#  'urge urine person',
#  'urine person suffering',
#  'person suffering heart',
#  'suffering heart diseases',
#  'heart diseases may',
#  'diseases may pain',
#  'may pain chest',
#  'pain chest symptoms',
#  'chest symptoms sometimes',
#  'symptoms sometimes last',
#  'sometimes last lifetime',
#  'last lifetime troubles',
#  'lifetime troubles lot',
#  'troubles lot old',
#  'lot old age',
#  'old age common',
#  'age common symptoms',
#  'common symptoms chronic',
#  'symptoms chronic diseases',
#  'chronic diseases fatigue',
#  'diseases fatigue pain',
#  'fatigue pain mental',
#  'pain mental stress',
#  'mental stress mood',
#  'stress mood disorders',
#  'mood disorders etcpeople',
#  'disorders etcpeople 40s',
#  'etcpeople 40s suffering',
#  '40s suffering chronic',
#  'suffering chronic health',
#  'chronic health issues',
#  'health issues notice',
#  'issues notice change',
#  'notice change physical',
#  'change physical appearance',
#  'physical appearance skin',
#  'appearance skin becoming',
#  'skin becoming dull',
#  'becoming dull start',
#  'dull start getting',
#  'start getting wrinkles',
#  'getting wrinkles issues',
#  'wrinkles issues make',
#  'issues make stay',
#  'make stay away',
#  'stay away social',
#  'away social life',
#  'social life family',
#  'life family gatherings',
#  'family gatherings people',
#  'gatherings people don’t',
#  'people don’t feel',
#  'don’t feel self-confident',
#  'feel self-confident used',
#  'self-confident used gradually',
#  'used gradually start',
#  'gradually start hating',
#  'start hating body',
#  'hating body makes',
#  'body makes prone',
#  'makes prone depression',
#  'prone depression anxiety',
#  'depression anxiety stress',
#  'anxiety stress builds',
#  'stress builds body',
#  'builds body leads',
#  'body leads frustration',
#  'leads frustration choleric',
#  'frustration choleric attitude',
#  'choleric attitude feel',
#  'attitude feel helpless',
#  'feel helpless daily',
#  'helpless daily activities',
#  'daily activities properly',
#  'activities properly feel',
#  'properly feel constant',
#  'feel constant need',
#  'constant need help',
#  'need help someonepeople',
#  'help someonepeople get',
#  'someonepeople get irritated',
#  'get irritated easily',
#  'irritated easily feel',
#  'easily feel difficulty',
#  'feel difficulty handling',
#  'difficulty handling relationships',
#  'handling relationships anxious',
#  'relationships anxious time',
#  'anxious time suffers',
#  'time suffers disturbed',
#  'suffers disturbed sleep',
#  'disturbed sleep people',
#  'sleep people often',
#  'people often seen',
#  'often seen complaining',
#  'seen complaining body',
#  'complaining body aches',
#  'body aches fatigue',
#  'aches fatigue lose',
#  'fatigue lose interests',
#  'lose interests things',
#  'interests things enjoyed',
#  'things enjoyed doinghow',
#  'enjoyed doinghow take',
#  'doinghow take care',
#  'take care ourselvesin',
#  'care ourselvesin people',
#  'ourselvesin people diseases',
#  'people diseases caused',
#  'diseases caused due',
#  'caused due bad',
#  'due bad lifestyle',
#  'bad lifestyle choices',
#  'lifestyle choices treatable',
#  'choices treatable proper',
#  'treatable proper medication',
#  'proper medication care',
#  'medication care discussed',
#  'care discussed people',
#  'discussed people late',
#  'people late 40s',
#  'late 40s vulnerable',
#  '40s vulnerable diseases',
#  'vulnerable diseases mean',
#  'diseases mean age',
#  'mean age groups',
#  'age groups safe',
#  'groups safe know',
#  'safe know prevention',
#  'know prevention better',
#  'prevention better cure',
#  'better cure it’s',
#  'cure it’s better',
#  'it’s better prevent',
#  'better prevent diseases',
#  'prevent diseases taking',
#  'diseases taking care',
#  'taking care healthy',
#  'care healthy habits',
#  'healthy habits adopted',
#  'habits adopted daily',
#  'adopted daily life',
#  'daily life eschew',
#  'life eschew diseases·',
#  'eschew diseases· work',
#  'diseases· work physically',
#  'work physically yoga',
#  'physically yoga walking',
#  'yoga walking jogging',
#  'walking jogging physical',
#  'jogging physical activity',
#  'physical activity interests',
#  'activity interests atleast',
#  'interests atleast 4',
#  'atleast 4 times',
#  '4 times week',
#  'times week staying',
#  'week staying healthy',
#  'staying healthy important',
#  'healthy important body',
#  'important body functions',
#  'body functions properly',
#  'functions properly safe',
#  'properly safe half',
#  'safe half diseases·',
#  'half diseases· keeping',
#  'diseases· keeping hydrated',
#  'keeping hydrated key',
#  'hydrated key healthy',
#  'key healthy lifestyle',
#  'healthy lifestyle drink',
#  'lifestyle drink water',
#  'drink water around',
#  'water around 6-8',
#  'around 6-8 glasses',
#  '6-8 glasses day',
#  'glasses day drinking',
#  'day drinking water',
#  'drinking water ensures',
#  'water ensures every',
#  'ensures every system',
#  'every system body',
#  'system body functions',
#  'body functions properly·',
#  'functions properly· keep',
#  'properly· keep check',
#  'keep check diet',
#  'check diet balanced',
#  'diet balanced meal',
#  'balanced meal replace',
#  'meal replace junk',
#  'replace junk food',
#  'junk food fruits',
#  'food fruits nuts',
#  'fruits nuts want',
#  'nuts want something',
#  'want something junk',
#  'something junk try',
#  'junk try keep',
#  'try keep rest',
#  'keep rest meals',
#  'rest meals day',
#  'meals day light·',
#  'day light· warm',
#  'light· warm water',
#  'warm water every',
#  'water every morning',
#  'every morning lemon',
#  'morning lemon removes',
#  'lemon removes toxins',
#  'removes toxins body',
#  'toxins body try',
#  'body try end',
#  'try end day',
#  'end day light',
#  'day light dinner',
#  'light dinner cup',
#  'dinner cup green',
#  'cup green tea',
#  'green tea automatically',
#  'tea automatically start',
#  'automatically start feeling',
#  'start feeling healthy',
#  'feeling healthy fresh·',
#  'healthy fresh· try',
#  'fresh· try get',
#  'try get atleast',
#  'get atleast 7-8',
#  'atleast 7-8 hours',
#  '7-8 hours sleep',
#  'hours sleep every',
#  'sleep every day',
#  'every day getting',
#  'day getting good',
#  'getting good night’s',
#  'good night’s sleep',
#  'night’s sleep essential',
#  'sleep essential days',
#  'essential days important',
#  'days important rest',
#  'important rest eyes',
#  'rest eyes brain',
#  'eyes brain well-rested',
#  'brain well-rested people',
#  'well-rested people seem',
#  'people seem handle',
#  'seem handle stress',
#  'handle stress better·',
#  'stress better· practise',
#  'better· practise meditation',
#  'practise meditation avoid',
#  'meditation avoid stress',
#  'avoid stress feel',
#  'stress feel happy',
#  'feel happy mentally',
#  'happy mentally physically·',
#  'mentally physically· last',
#  'physically· last least',
#  'last least spend',
#  'least spend time',
#  'spend time things',
#  'time things makes',
#  'things makes heart',
#  'makes heart happy',
#  'heart happy family',
#  'happy family dinners',
#  'family dinners long',
#  'dinners long conversations',
#  'long conversations look',
#  'conversations look old',
#  'look old photographs',
#  'old photographs paint',
#  'photographs paint travel',
#  'paint travel read',
#  'travel read write',
#  'read write whatever',
#  'write whatever used',
#  'whatever used youngto',
#  'used youngto conclude',
#  'youngto conclude know',
#  'conclude know pandemic',
#  'know pandemic lifestyle',
#  'pandemic lifestyle affected',
#  'lifestyle affected lot',
#  'affected lot it’s',
#  'lot it’s difficult',
#  'it’s difficult maintain',
#  'difficult maintain mental',
#  'maintain mental physical',
#  'mental physical well-being',
#  'physical well-being keeping',
#  'well-being keeping faith',
#  'keeping faith trusting',
#  'faith trusting way',
#  'trusting way achieving',
#  'way achieving people',
#  'achieving people late',
#  'people late 40s',
#  'late 40s take',
#  '40s take care',
#  'take care avoid',
#  'care avoid health',
#  'avoid health risks',
#  'health risks need',
#  'risks need worry',
#  'need worry stress',
#  'worry stress advances',
#  'stress advances medicine',
#  'advances medicine made',
#  'medicine made treatment',
#  'made treatment diseases',
#  'treatment diseases easy',
#  'diseases easy it’s',
#  'easy it’s always',
#  'it’s always better',
#  'always better eschew',
#  'better eschew things',
#  'eschew things affect',
#  'things affect us',
#  'affect us future',
#  'us future people',
#  'future people chronic',
#  'people chronic illness',
#  'chronic illness face',
#  'illness face extreme',
#  'face extreme levels',
#  'extreme levels stress',
#  'levels stress make',
#  'stress make sure',
#  'make sure follow',
#  'sure follow health',
#  'follow health care',
#  'health care tips',
#  'care tips stress',
#  'tips stress management']

# %%
word_count3 = {}
 
for word in l3:
    if word in word_count3:
        word_count3[word] += 1
    else:
        word_count3[word] = 1

# %%
c = Counter(word_count3)
 
    # returns the most occurring elements
t = c.most_common(50)
top3 = c.most_common(1)
density3 = (top3[0][1]/len(l3))*100
print(t)
print(top3)
top3.append(density3)
# Out:
# [('people late 40s', 4), ('among people late', 2), ('chronic diseases like', 1), ('diseases like diabetes', 1), ('like diabetes heart', 1), ('diabetes heart attacks', 1), ('heart attacks cancer', 1), ('attacks cancer arthritis', 1), ('cancer arthritis etc', 1), ('arthritis etc described', 1), ('etc described health', 1), ('described health issues', 1), ('health issues last', 1), ('issues last around', 1), ('last around year', 1), ('around year issues', 1), ('year issues require', 1), ('issues require regular', 1), ('require regular medication', 1), ('regular medication medical', 1), ('medication medical treatments', 1), ('medical treatments limitations', 1), ('treatments limitations food', 1), ('limitations food alcohol', 1), ('food alcohol may', 1), ('alcohol may cause', 1), ('may cause difficulty', 1), ('cause difficulty everyday', 1), ('difficulty everyday activities', 1), ('everyday activities getting', 1), ('activities getting dressed', 1), ('getting dressed going', 1), ('dressed going toilet', 1), ('going toilet climbing', 1), ('toilet climbing stairs', 1), ('climbing stairs etc', 1), ('stairs etc diseases', 1), ('etc diseases become', 1), ('diseases become common', 1), ('become common among', 1), ('common among people', 1), ('late 40s may', 1), ('40s may go', 1), ('may go away', 1), ('go away time', 1), ('away time provided', 1), ('time provided proper', 1), ('provided proper medical', 1), ('proper medical treatment', 1), ('medical treatment cases', 1)]
# [('people late 40s', 4)]

# %%
f = []
f.append(top1)
f.append(top2)
f.append(top3)
f
# Out:
# [[('people', 16), 2.8933092224231465],
#  [('people late', 5), 0.9057971014492754],
#  [('people late 40s', 4), 0.7259528130671506]]
